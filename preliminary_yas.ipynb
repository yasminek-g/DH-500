# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv("data.csv")
display(df.head())

print("Number of columns:", len(df.columns.tolist()))
for col in df.columns.tolist():
    print(col)
# Out:
#    incident_id report_id  thread Validated By Title Tags  date_coded  \
# 0           74         2     NaN          NaN   NaN  NaN  2023-10-29
# 1           75         3     NaN          NaN   NaN  NaN  2023-10-29
# 2           76         4     NaN          NaN   NaN  NaN  2023-10-29
# 3           70         5     NaN          NaN   NaN  NaN  2023-10-23
# 4           77         6     NaN          NaN   NaN  NaN  2023-10-29
#
#                                                  url source file  \
# 0  https://twitter.com/MikaelThalen/status/150412...    NaN  NaN
# 1  https://twitter.com/ThePatriotOasis/status/163...    NaN  NaN
# 2  https://twitter.com/SabrinaHalper/status/17136...    NaN  NaN
# 3  https://twitter.com/MechaOrvo/status/171479783...    NaN  NaN
# 4  https://twitter.com/NotPoliticians/status/1714...    NaN  NaN
#
#   file_with_watermark screenshot date_posted format  \
# 0                 NaN        NaN  2022-03-16  video
# 1                 NaN        NaN  2023-02-27  video
# 2                 NaN        NaN  2023-10-15  video
# 3                 NaN        NaN  2023-10-18  video
# 4                 NaN        NaN  2023-10-17  video
#
#                                           transcript  \
# 0  Ukrainian: шановні захисники бути Президентом ...
# 1  The illegal Russian offensive has been swift, ...
# 2  My time is coming to an end, and I would like ...
# 3  "Israel has hypnotized the world. May Allah aw...
# 4  "The very first thing we have to do is raise t...
#
#                                      summary_content             type  \
# 0  The deepfake is a video of President Volodymyr...        cheapfake
# 1  President Biden is addressing an audience and ...  unclear/unknown
# 2  Screenshot of a TikTok video showing Warren Bu...         deepfake
# 3  The video shows Donald Trump giving a speech a...         deepfake
# 4  The deepfake is a collection of videos showing...         deepfake
#
#                                         comment_type  \
# 0  https://www.npr.org/2022/03/16/1087062648/deep...
# 1                                                NaN
# 2                                                NaN
# 3                        Completely fabricated video
# 4                                                NaN
#
#    Needs external review (type) HiveModeration_Score sharer_faketype  \
# 0                           NaN                  NaN            fake
# 1                           NaN                  NaN  real_authentic
# 2                           NaN                  NaN            fake
# 3                           NaN                  NaN  real_authentic
# 4                           NaN                  NaN            fake
#
#    Needs External Review (sharer_faketype)  external_verification  \
# 0                                      NaN          verified_fake
# 1                                      NaN          verified_fake
# 2                                      NaN  authenticity_disputed
# 3                                      NaN          verified_fake
# 4                                      NaN  authenticity_disputed
#
#    Needs External Review (external_verification)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                                   links_verification  \
# 0  https://www.npr.org/2022/03/16/1087062648/deep...
# 1  The text posted with the deepfake say, "BREAKI...
# 2                                                NaN
# 3  Comments on the post saying that the post is f...
# 4                                                NaN
#
#                                        evidence_fake watermark  \
# 0  Poor video quality, mouth doesn't match words ...       yes
# 1            Biden does not usually talk that fast.        yes
# 2  The mouth movements sometimes do not line up w...        no
# 3         Trump's mouth looks awkward when speaking.        no
# 4                                                NaN       yes
#
#    Needs External Verification (watermark) likes views comments shares  \
# 0                                      NaN   798   NaN      145    789
# 1                                      NaN  3.3k   NaN    3.1k    4.3k
# 2                                      NaN    17   NaN        3      0
# 3                                      NaN   528   NaN       53    135
# 4                                      NaN    18   NaN        0     13
#
#      original_source_name original_source_username  \
# 0                     NaN                      NaN
# 1     The Post Millennial                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4  Voters Not Politicians                      NaN
#
#   Needs External Review (Original Source Name) original_source_type  \
# 0                                          NaN      unclear_unknown
# 1                                          NaN                group
# 2                                          NaN      unclear_unknown
# 3                                          NaN      unclear_unknown
# 4                                          NaN                group
#
#   Needs External Review (Original Source Type) original_source_actor_type  \
# 0                                          NaN            unclear_unknown
# 1                                          NaN                private_ngo
# 2                                          NaN            unclear_unknown
# 3                                          NaN            unclear_unknown
# 4                                          NaN                private_ngo
#
#    Needs External Review (Original Source Actor Type) original_source_country  \
# 0                                                NaN                       NA
# 1                                                NaN                  Canada
# 2                                                NaN                       NA
# 3                                                NaN           United States
# 4                                                NaN           United States
#
#   other_original_source_country  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    Needs External Review (Original Source Country)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                      comments_coding_original_source             sharer_name  \
# 0                                     User's profile           Mikael Thalen
# 1                                                NaN       The Patriot Oasis
# 2                                     User's profile          Sabrina Halper
# 3  The user's profile mentions Corsica as their l...                    Orvo
# 4                                                NaN  Voters Not Politicians
#
#   other_sharer_name  Needs External Review (Sharer Name) sharer_username  \
# 0               NaN                                  NaN             NaN
# 1               NaN                                  NaN             NaN
# 2               NaN                                  NaN             NaN
# 3               NaN                                  NaN             NaN
# 4               NaN                                  NaN             NaN
#
#         sharer_type  Needs External Review (Sharer Type)       sharer_job  \
# 0        individual                                  NaN       journalist
# 1             group                                  NaN  unclear_unknown
# 2        individual                                  NaN      random_user
# 3  non-identifiable                                  NaN      random_user
# 4             group                                  NaN      random_user
#
#    Needs External Review (Sharer Job) high_impact_comment  \
# 0                                 NaN                 NaN
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
#
#              sharer_country other_sharer_country  \
# 0                  unknown                   NaN
# 1                  unknown                   NaN
# 2  United States of America                  NaN
# 3  United States of America                  NaN
# 4  United States of America                  NaN
#
#   Needs External Review (Sharer Country)    sharer_city other_sharer_city  \
# 0                                    NaN        unknown               NaN
# 1                                    NaN        unknown               NaN
# 2                                    NaN  New York City               NaN
# 3                                    NaN            NaN               NaN
# 4                                    NaN       Michigan               NaN
#
#    Needs External Review (Sharer City)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                               comments_sharer_coding          target_name  \
# 0                                     User's profile  Volodymyr Zelenskyy
# 1  The user's profile did not add any information...            Joe Biden
# 2                                     User's profile        Warren Buffet
# 3  The sharer's profile says Texas, but unknown i...        Donald Trump
# 4                                     User's profile          US Congress
#
#        target_one_name target_one_name_other target_one_sentiment  \
# 0  Volodymyr Zelenskyy                   NaN              Neutral
# 1            Joe Biden                   NaN              Neutral
# 2        Warren Buffet                   NaN              Neutral
# 3         Donald Trump                   NaN                  NaN
# 4          US Congress                   NaN              Neutral
#
#   target_one_type_macro target_one_type_micro        target_one_country  \
# 0            individual            politician                   Ukraine
# 1            individual            politician  United States of America
# 2            individual         public_figure  United States of America
# 3                   NaN                   NaN                       NaN
# 4                 group       unclear_unknown  United States of America
#
#   target_one_country_other target_one_responded  \
# 0                      NaN              checked
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                  NaN
#
#                                  target_one_response target_two_name  \
# 0  https://x.com/HannaLiubakova/status/1504056101...             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#   target_two_name_other target_two_sentiment target_two_type_macro  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                   NaN                  NaN                   NaN
#
#   target_two_type_micro target_two_country target_two_country_other  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
# 3                   NaN                NaN                      NaN
# 4                   NaN                NaN                      NaN
#
#    target_two_responded  target_two_response target_three_name  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# 2                   NaN                  NaN               NaN
# 3                   NaN                  NaN               NaN
# 4                   NaN                  NaN               NaN
#
#   target_three_name_other target_three_sentiment target_three_type_macro  \
# 0                     NaN                    NaN                     NaN
# 1                     NaN                    NaN                     NaN
# 2                     NaN                    NaN                     NaN
# 3                     NaN                    NaN                     NaN
# 4                     NaN                    NaN                     NaN
#
#   target_three_type_micro target_three_country  target_three_country_other  \
# 0                     NaN                  NaN                         NaN
# 1                     NaN                  NaN                         NaN
# 2                     NaN                  NaN                         NaN
# 3                     NaN                  NaN                         NaN
# 4                     NaN                  NaN                         NaN
#
#    target_three_responded  target_three_response target_four_name  \
# 0                     NaN                    NaN              NaN
# 1                     NaN                    NaN              NaN
# 2                     NaN                    NaN              NaN
# 3                     NaN                    NaN              NaN
# 4                     NaN                    NaN              NaN
#
#    target_four_name_other target_four_sentiment target_four_type_macro  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   target_four_type_micro target_four_country  target_four_country_other  \
# 0                    NaN                 NaN                        NaN
# 1                    NaN                 NaN                        NaN
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                        NaN
# 4                    NaN                 NaN                        NaN
#
#    target_four_responded  target_four_response target_five_name  \
# 0                    NaN                   NaN              NaN
# 1                    NaN                   NaN              NaN
# 2                    NaN                   NaN              NaN
# 3                    NaN                   NaN              NaN
# 4                    NaN                   NaN              NaN
#
#    target_five_name_other target_five_sentiment target_five_type_macro  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   target_five_type_micro target_five_country  target_five_country_other  \
# 0                    NaN                 NaN                        NaN
# 1                    NaN                 NaN                        NaN
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                        NaN
# 4                    NaN                 NaN                        NaN
#
#    target_five_responded  target_five_response target_six_name  \
# 0                    NaN                   NaN             NaN
# 1                    NaN                   NaN             NaN
# 2                    NaN                   NaN             NaN
# 3                    NaN                   NaN             NaN
# 4                    NaN                   NaN             NaN
#
#    target_six_name_other target_six_sentiment target_six_type_macro  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 3                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
#
#   target_six_type_micro target_six_country  target_six_country_other  \
# 0                   NaN                NaN                       NaN
# 1                   NaN                NaN                       NaN
# 2                   NaN                NaN                       NaN
# 3                   NaN                NaN                       NaN
# 4                   NaN                NaN                       NaN
#
#    target_six_responded  target_six_response target_seven_name  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# 2                   NaN                  NaN               NaN
# 3                   NaN                  NaN               NaN
# 4                   NaN                  NaN               NaN
#
#    target_seven_name_other target_seven_sentiment target_seven_type_macro  \
# 0                      NaN                    NaN                     NaN
# 1                      NaN                    NaN                     NaN
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 4                      NaN                    NaN                     NaN
#
#   target_seven_type_micro target_seven_country  target_seven_country_other  \
# 0                     NaN                  NaN                         NaN
# 1                     NaN                  NaN                         NaN
# 2                     NaN                  NaN                         NaN
# 3                     NaN                  NaN                         NaN
# 4                     NaN                  NaN                         NaN
#
#    target_seven_responded  target_seven_response target_eight_name  \
# 0                     NaN                    NaN               NaN
# 1                     NaN                    NaN               NaN
# 2                     NaN                    NaN               NaN
# 3                     NaN                    NaN               NaN
# 4                     NaN                    NaN               NaN
#
#    target_eight_name_other target_eight_sentiment target_eight_type_macro  \
# 0                      NaN                    NaN                     NaN
# 1                      NaN                    NaN                     NaN
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 4                      NaN                    NaN                     NaN
#
#   target_eight_type_micro target_eight_country  target_eight_country_other  \
# 0                     NaN                  NaN                         NaN
# 1                     NaN                  NaN                         NaN
# 2                     NaN                  NaN                         NaN
# 3                     NaN                  NaN                         NaN
# 4                     NaN                  NaN                         NaN
#
#    target_eight_responded  target_eight_response target_nine_name  \
# 0                     NaN                    NaN              NaN
# 1                     NaN                    NaN              NaN
# 2                     NaN                    NaN              NaN
# 3                     NaN                    NaN              NaN
# 4                     NaN                    NaN              NaN
#
#    target_nine_name_other target_nine_sentiment target_nine_type_macro  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   target_nine_type_micro target_nine_country  target_nine_country_other  \
# 0                    NaN                 NaN                        NaN
# 1                    NaN                 NaN                        NaN
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                        NaN
# 4                    NaN                 NaN                        NaN
#
#    target_nine_responded  target_nine_response  target_ten_name  \
# 0                    NaN                   NaN              NaN
# 1                    NaN                   NaN              NaN
# 2                    NaN                   NaN              NaN
# 3                    NaN                   NaN              NaN
# 4                    NaN                   NaN              NaN
#
#    target_ten_name_other  target_ten_sentiment  target_ten_type_macro  \
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
# 3                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
#
#    target_ten_type_micro  target_ten_country  target_ten_country_other  \
# 0                    NaN                 NaN                       NaN
# 1                    NaN                 NaN                       NaN
# 2                    NaN                 NaN                       NaN
# 3                    NaN                 NaN                       NaN
# 4                    NaN                 NaN                       NaN
#
#    target_ten_responded  target_ten_response  \
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
#
#    Needs External Review (Target Name) target_type_macro  \
# 0                                  NaN        individual
# 1                                  NaN        individual
# 2                                  NaN        individual
# 3                                  NaN        individual
# 4                                  NaN             group
#
#   Needs External Review (Target Type Macro)             target_type_micro  \
# 0                                       NaN  politician,government_entity
# 1                                       NaN                    politician
# 2                                       NaN                 public_figure
# 3                                       NaN                    politician
# 4                                       NaN             government_entity
#
#    Needs External Review (Target Type Micro)            target_country  \
# 0                                        NaN                   Ukraine
# 1                                        NaN  United States of America
# 2                                        NaN  United States of America
# 3                                        NaN  United States of America
# 4                                        NaN  United States of America
#
#   other_target_country  Needs External Review (Target Country)  \
# 0                  NaN                                     NaN
# 1                  NaN                                     NaN
# 2                  NaN                                     NaN
# 3                  NaN                                     NaN
# 4                  NaN                                     NaN
#
#   target_responded                             comments_target_coding  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN  There is no response by Macron in the comments...
# 4              NaN                                                NaN
#
#   target_response deepfake_content_depicts  \
# 0             NaN             war_violence
# 1             NaN             war_violence
# 2             NaN                    crime
# 3             NaN             crisis_event
# 4             NaN      deepfake_regulation
#
#    Needs External Review (Content Depicts)     harm_depicted  \
# 0                                      NaN      human_rights
# 1                                      NaN             other
# 2                                      NaN             other
# 3                                      NaN    discrimination
# 4                                      NaN  non-identifiable
#
#    Needs External Review (Harm Depicted)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                               comments_content_topic  \
# 0                                                NaN
# 1                                                NaN
# 2  The deepfake causes discriminatory harm becaus...
# 3  The cheapfake image relates to tensions betwee...
# 4                 The harm is to Trump's character.
#
#           social_policy_sector  Needs External Review (Social Policy Sector)  \
# 0  military_public_safety_govt                                           NaN
# 1  military_public_safety_govt                                           NaN
# 2                      finance                                           NaN
# 3  military_public_safety_govt                                           NaN
# 4  military_public_safety_govt                                           NaN
#
#                        comments_social_policy_sector  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The deepfake involves candidates running for p...
# 4                                                NaN
#
#                                     context_deepfake  \
# 0  Russia invaded Ukraine, and there is now an on...
# 1  There is ongoing conflict in Ukraine, and incr...
# 2  Warren Buffett is one of the most successful i...
# 3  Israel is currently at war with Hamas, and Tru...
# 4  AI-generated political advertisments have been...
#
#    Needs External Review (Context Deepfake)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                 text_around_deepfake           harm_evidence  \
# 0  A deepfake of Ukrainian President Volodymyr Ze...                   other
# 1  BREAKING: Biden calls for a national draft. Me...                   other
# 2  "I’ve seen so many deep fake videos on TikTok ...        non_identifiable
# 3  BREAKING: @realDonaldTrump has given a stateme...  political_interference
# 4  Using artificial intelligence to create deepfa...        non_identifiable
#
#   Needs External Review (Harm Evidence)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                               comments_harms_context  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  There is no evidence of harms to DeSantis from...
# 4                                                NaN
#
#                        communication_goal  \
# 0                       harm_human_rights
# 1                              false_info
# 2                               education
# 3  false_info,harm_political_interference
# 4                      education,activism
#
#    Needs External Review (Communication Goal)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                          comments_communication_goal             core_frame  \
# 0                                                NaN         human_interest
# 1                                                NaN               conflict
# 2                                                NaN  economic_consequences
# 3  The included text on the sharer's post points ...      conflict,morality
# 4  "Epstein didn't kill himself" became a popular...         responsibility
#
#    Needs External Review (Core Frame)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                  comments_core_frame  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pubs and pints are connected to British cultur...
# 4                                                NaN
#
#                                               hero  \
# 0                              Ukrainian soldiers
# 1  The US military/ freedom for Ukraine and Taiwan
# 2                                    Warren Buffet
# 3                      Trump for denouncing Israel
# 4                                   AI regulations
#
#    Needs External Review (Hero)                                    villain  \
# 0                           NaN  Ukrainain soliders are dying in the war.
# 1                           NaN                          China and Russia
# 2                           NaN                        Economic inequality
# 3                           NaN                              Israel and US
# 4                           NaN                       Lack of regulations
#
#    Needs External Review (Villain)  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                                                 plot  \
# 0  President Zelensky is calling for troops to st...
# 1  Increased tensions in Ukraine and Taiwan have ...
# 2  Warren Buffet is wanting to give away some of ...
# 3         Trump is denouncing the actions of Israel.
# 4  AI is being used to create pThe current lack o...
#
#    Needs External Review (Plot)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                                moral  \
# 0  Zelenksy thinks Ukraine is losing the war so h...
# 1  The opening of the draft is inevitable due to ...
# 2  Warren Buffet thinks giving his money away to ...
# 3                Trump is standing up for Palestine.
# 4  AI is being used to create political ads that ...
#
#   Needs External Review (Moral)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                            comments_policy_narrative Validated
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  Images could be interpreted as Macron being th...       NaN
# 4                                                NaN       NaN
# Number of columns: 191
# incident_id
# report_id
# thread
# Validated By
# Title
# Tags
# date_coded
# url
# source
# file
# file_with_watermark
# screenshot
# date_posted
# format
# transcript
# summary_content
# type
# comment_type
# Needs external review (type)
# HiveModeration_Score
# sharer_faketype
# Needs External Review (sharer_faketype)
# external_verification
# Needs External Review (external_verification)
# links_verification
# evidence_fake
# watermark
# Needs External Verification (watermark)
# likes
# views
# comments
# shares
# original_source_name
# original_source_username
# Needs External Review (Original Source Name)
# original_source_type
# Needs External Review (Original Source Type)
# original_source_actor_type
# Needs External Review (Original Source Actor Type)
# original_source_country
# other_original_source_country
# Needs External Review (Original Source Country)
# comments_coding_original_source
# sharer_name
# other_sharer_name
# Needs External Review (Sharer Name)
# sharer_username
# sharer_type
# Needs External Review (Sharer Type)
# sharer_job
# Needs External Review (Sharer Job)
# high_impact_comment
# sharer_country
# other_sharer_country
# Needs External Review (Sharer Country)
# sharer_city
# other_sharer_city
# Needs External Review (Sharer City)
# comments_sharer_coding
# target_name
# target_one_name
# target_one_name_other
# target_one_sentiment
# target_one_type_macro
# target_one_type_micro
# target_one_country
# target_one_country_other
# target_one_responded
# target_one_response
# target_two_name
# target_two_name_other
# target_two_sentiment
# target_two_type_macro
# target_two_type_micro
# target_two_country
# target_two_country_other
# target_two_responded
# target_two_response
# target_three_name
# target_three_name_other
# target_three_sentiment
# target_three_type_macro
# target_three_type_micro
# target_three_country
# target_three_country_other
# target_three_responded
# target_three_response
# target_four_name
# target_four_name_other
# target_four_sentiment
# target_four_type_macro
# target_four_type_micro
# target_four_country
# target_four_country_other
# target_four_responded
# target_four_response
# target_five_name
# target_five_name_other
# target_five_sentiment
# target_five_type_macro
# target_five_type_micro
# target_five_country
# target_five_country_other
# target_five_responded
# target_five_response
# target_six_name
# target_six_name_other
# target_six_sentiment
# target_six_type_macro
# target_six_type_micro
# target_six_country
# target_six_country_other
# target_six_responded
# target_six_response
# target_seven_name
# target_seven_name_other
# target_seven_sentiment
# target_seven_type_macro
# target_seven_type_micro
# target_seven_country
# target_seven_country_other
# target_seven_responded
# target_seven_response
# target_eight_name
# target_eight_name_other
# target_eight_sentiment
# target_eight_type_macro
# target_eight_type_micro
# target_eight_country
# target_eight_country_other
# target_eight_responded
# target_eight_response
# target_nine_name
# target_nine_name_other
# target_nine_sentiment
# target_nine_type_macro
# target_nine_type_micro
# target_nine_country
# target_nine_country_other
# target_nine_responded
# target_nine_response
# target_ten_name
# target_ten_name_other
# target_ten_sentiment
# target_ten_type_macro
# target_ten_type_micro
# target_ten_country
# target_ten_country_other
# target_ten_responded
# target_ten_response
# Needs External Review (Target Name)
# target_type_macro
# Needs External Review (Target Type Macro)
# target_type_micro
# Needs External Review (Target Type Micro)
# target_country
# other_target_country
# Needs External Review (Target Country)
# target_responded
# comments_target_coding
# target_response
# deepfake_content_depicts
# Needs External Review (Content Depicts)
# harm_depicted
# Needs External Review (Harm Depicted)
# comments_content_topic
# social_policy_sector
# Needs External Review (Social Policy Sector)
# comments_social_policy_sector
# context_deepfake
# Needs External Review (Context Deepfake)
# text_around_deepfake
# harm_evidence
# Needs External Review (Harm Evidence)
# comments_harms_context
# communication_goal
# Needs External Review (Communication Goal)
# comments_communication_goal
# core_frame
# Needs External Review (Core Frame)
# comments_core_frame
# hero
# Needs External Review (Hero)
# villain
# Needs External Review (Villain)
# plot
# Needs External Review (Plot)
# moral
# Needs External Review (Moral)
# comments_policy_narrative
# Validated

# %% [markdown]
# A lot of columns; check for which ones are redundant (almost all NaN). Find most relevant ones.

# %%
all_nan_cols = df.columns[df.isna().all()]
print("Columns with all NaN values:", len(list(all_nan_cols)))

threshold = 0.99
high_nan_cols = df.columns[df.isna().mean() > threshold]
print("Columns with more than 99% NaN values:", len(list(high_nan_cols)))

# Find most relevant columns
df_relevant = df.drop(columns=high_nan_cols)
print("\nRemaining columns:", len(df_relevant.columns.to_list()))
for relev in df_relevant.columns.to_list():
    print(relev)
# Out:
# Columns with all NaN values: 61
# Columns with more than 99% NaN values: 112
#
# Remaining columns: 79
# incident_id
# report_id
# Validated By
# Title
# date_coded
# url
# file
# screenshot
# date_posted
# format
# transcript
# summary_content
# type
# comment_type
# HiveModeration_Score
# sharer_faketype
# external_verification
# links_verification
# evidence_fake
# watermark
# likes
# views
# comments
# shares
# original_source_name
# original_source_type
# original_source_actor_type
# original_source_country
# comments_coding_original_source
# sharer_name
# other_sharer_name
# sharer_username
# sharer_type
# sharer_job
# high_impact_comment
# sharer_country
# other_sharer_country
# sharer_city
# other_sharer_city
# comments_sharer_coding
# target_name
# target_one_name
# target_one_sentiment
# target_one_type_macro
# target_one_type_micro
# target_one_country
# target_two_name
# target_two_sentiment
# target_two_type_macro
# target_two_type_micro
# target_two_country
# target_three_name
# target_three_sentiment
# target_three_type_macro
# target_three_type_micro
# target_three_country
# target_type_macro
# target_type_micro
# target_country
# comments_target_coding
# deepfake_content_depicts
# harm_depicted
# comments_content_topic
# social_policy_sector
# comments_social_policy_sector
# context_deepfake
# text_around_deepfake
# harm_evidence
# comments_harms_context
# communication_goal
# comments_communication_goal
# core_frame
# comments_core_frame
# hero
# villain
# plot
# moral
# comments_policy_narrative
# Validated

# %% [markdown]
# ## Social platforms

# %%
from urllib.parse import urlparse

# Determine social platform by extracting the domain from the URL
df['domain'] = df['url'].apply(lambda x: urlparse(x).netloc if pd.notnull(x) else None)
print("Social platform counts:\n", df['domain'].value_counts())
# Out:
# Social platform counts:
#  domain
# x.com                                     601
# twitter.com                               159
# www.tiktok.com                             39
# youtu.be                                   31
# www.youtube.com                            22
# www.instagram.com                          18
# miro.medium.com                            16
# www.facebook.com                           14
# farid.berkeley.edu                         12
# www.reddit.com                              8
# truthsocial.com                             7
# archive.is                                  6
#                                             4
# web.archive.org                             3
# www.cnn.com                                 3
# www.alternet.org                            3
# techcrunch.com                              3
# archive.li                                  2
# static01.nytimes.com                        2
# nypost.com                                  2
# archive.ph                                  1
# www.twitch.tv                               1
# www-dailymail-co-uk.cdn.ampproject.org      1
# thumbnails.texastribune.org                 1
# creator.nightcafe.studio                    1
# tungsten.run                                1
# untappedcities.com                          1
# www.reuters.com                             1
# perma.cc                                    1
# www.washingtonpost.com                      1
# www.reforma.com                             1
# static01.nyt.com                            1
# m.independent.ie                            1
# www.news.com.au                             1
# www.theguardian.com                         1
# www.politico.com                            1
# www.snopes.com                              1
# Name: count, dtype: int64

# %% [markdown]
# We can see that the most popular deepfake/cheapfake platforms are X/Twitter, TikTok, YouTube, Instagram and Facebook. We have some other websites to explore too, such as Medium, Berkeley and TruthSocial, etc.

# %%
# Count rows per year in the date_posted column
df['date_posted'] = pd.to_datetime(df['date_posted'], errors='coerce')
df['year'] = df['date_posted'].dt.year
print("Rows per year:\n", df['year'].value_counts())
# Out:
# Rows per year:
#  year
# 2024.0    617
# 2023.0    240
# 2020.0     52
# 2021.0     35
# 2022.0     16
# 2019.0      9
# 2018.0      2
# 2016.0      1
# 2025.0      1
# Name: count, dtype: int64

# %% [markdown]
# We see that most posts were made in 2024 and 2023, which can provide a sufficient basis for our analysis (857 rows).

# %%
# Identify rows with media 
media_rows = df[df['file'].notna()]
print("Number of rows with media:", media_rows.shape[0])
print("Proportion with media:", media_rows.shape[0]/len(df))
# Out:
# Number of rows with media: 928
# Proportion with media: 0.9508196721311475

# %% [markdown]
# Around 95% of the rows have media, which is promising for some image processing analysis.

# %%
print("Format counts:\n", df['format'].value_counts())
print("\nType counts:\n", df['type'].value_counts())
print("\nSharer faketype counts:\n", df['sharer_faketype'].value_counts())
print("\nExternal verification counts:\n", df['external_verification'].value_counts())
# Out:
# Format counts:
#  format
# image    646
# video    330
# Name: count, dtype: int64
#
# Type counts:
#  type
# deepfake           803
# unclear/unknown     89
# cheapfake           82
# real                 1
# Name: count, dtype: int64
#
# Sharer faketype counts:
#  sharer_faketype
# fake              468
# unclear           350
# real_authentic    157
# Name: count, dtype: int64
#
# External verification counts:
#  external_verification
# unknown                  455
# verified_fake            325
# authenticity_disputed    156
# verified_real             39
# Name: count, dtype: int64

# %% [markdown]
# The majority of media is images with a significant portion of videos. We have enough on deepfakes to fully focus on it (and not worry about the nuances/differences between deepfakes and cheapfakes, etc). Most of the sharers of these posts deem their posts to be fake, but an equally significant portion does not explicitly state anything (350 sharers being unclear). Huge lack of external verification which can be a potential weakness.

# %% [markdown]
# # Potential ways to filter the data
#
# We will also filter away all the high-NaN columns as well for all options.

# %%
df = df.drop(columns=high_nan_cols)

# %% [markdown]
# ### 1. 2023-2024 analysis of deepfake images/videos that have been verified

# %%
df1 = df[
    (df['year'].isin([2023, 2024])) & 
    (df['type'] == 'deepfake') &       
    (df['file'].notna()) &             
    (df['external_verification'] != 'unknown')
]

# %%
print(df1.shape)
display(df1)
# Out:
# (340, 81)
#      incident_id report_id      Validated By  \
# 16           203        17               NaN
# 18           186        18               NaN
# 20           187        19               NaN
# 31           201        25               NaN
# 32           283        26               NaN
# ..           ...       ...               ...
# 917         1002       543               NaN
# 925         1011       444  Isabella Mulford
# 957         1044       594       Alaina Hall
# 958         1045       533               NaN
# 960         1047       543               NaN
#
#                                   Title  date_coded  \
# 16                                  NaN  2024-02-12
# 18                                  NaN  2024-02-04
# 20                                  NaN  2024-02-05
# 31                                  NaN  2024-02-09
# 32                                  NaN  2024-03-04
# ..                                  ...         ...
# 917                                 NaN  2025-03-04
# 925  Donald Trump and Elon Musk dancing  2025-03-05
# 957                                 NaN  2025-03-05
# 958                                 NaN  2025-03-05
# 960                                 NaN  2025-03-05
#
#                                                    url  \
# 16   https://twitter.com/DouglasLucas/status/171631...
# 18   https://twitter.com/21WIRE/status/165300993699...
# 20       https://www.facebook.com/reel/894486844951526
# 31   https://twitter.com/JackPosobiec/status/163383...
# 32   https://www.reddit.com/r/ChatGPT/comments/156h...
# ..                                                 ...
# 917  https://x.com/cattocrunch/status/1825860652847...
# 925  https://x.com/realDonaldTrump/status/182406968...
# 957  https://x.com/Jere_Memez/status/18250285930359...
# 958  https://x.com/YourMomsHo42215/status/182532763...
# 960  https://x.com/cattocrunch/status/1825860652847...
#
#                                                   file  \
# 16   Screenshot 2024-02-12 at 12.47.24 PM.png (http...
# 18   "Patrick Henningsen on X_ _⭕️ Granted, this mu...
# 20   deepfake 19.html (https://v5.airtableuserconte...
# 31   Screenshot 2024-02-09 134519.png (https://v5.a...
# 32   deepfake 26.html (https://v5.airtableuserconte...
# ..                                                 ...
# 917  GVQyp6pWAAAk6cw.jpg (https://v5.airtableuserco...
# 925  ScreenRecording_03-05-2025 14-04-06_1.mov (htt...
# 957  pdid 594.jpg (https://v5.airtableusercontent.c...
# 958  pdid 533.jpg (https://v5.airtableusercontent.c...
# 960  GVQyp6pWAAAk6cw.jpg (https://v5.airtableuserco...
#
#                                             screenshot date_posted format  \
# 16                                                 NaN  2023-10-23  image
# 18                                                 NaN  2023-05-01  video
# 20                                                 NaN  2023-05-03  video
# 31                                                 NaN  2023-03-09  video
# 32                                                 NaN  2023-07-22  video
# ..                                                 ...         ...    ...
# 917  Screenshot 2025-03-03 210934.png (https://v5.a...  2024-08-20  image
# 925  Screenshot 2025-03-05 at 2.04.31 PM.png (https...  2024-08-15  video
# 957  Screenshot 2024-10-30 at 12.54.40 PM.png (http...  2024-08-18  image
# 958  Screen Shot 2025-03-05 at 4.05.44 PM.png (http...  2024-08-18  image
# 960  Screenshot 2025-03-03 210934.png (https://v5.a...  2024-08-20  image
#
#                                             transcript  \
# 16                                                 NaN
# 18   "Today is today, and yesterday was today yeste...
# 20   “Today is today, and yesterday is today yester...
# 31   I'll tell you something the deepfake that Jack...
# 32   "Highly anticipated season for reloaded update...
# ..                                                 ...
# 917                                                NaN
# 925  Stayin' Alive by the Bee Gees is playing in th...
# 957                                                NaN
# 958                                                NaN
# 960                                                NaN
#
#                                        summary_content      type  \
# 16   Two polaroid photographs, the one one the righ...  deepfake
# 18   Kamala Harris is speaking at a rally and her s...  deepfake
# 20   The sharer posted a video showing her reacting...  deepfake
# 31   AOC announcing her opinions with regards to ho...  deepfake
# 32   The video shows a news clip from Tucker Carlso...  deepfake
# ..                                                 ...       ...
# 917  The image depicts Donald Trump standing in an ...  deepfake
# 925         Donald Trump and Elon Musk are dancing. \n  deepfake
# 957  It is a screenshot of Donald Trump's post of K...  deepfake
# 958  It is an image of Taylor Swift dressed in a ty...  deepfake
# 960  The image depicts Donald Trump standing in an ...  deepfake
#
#                                           comment_type HiveModeration_Score  \
# 16   The caption of the post states that the photo ...             100% AI
# 18   AP News Article identifies the video as a deep...                  NaN
# 20   The video of Kamala Harris has been confirmed ...                  NaN
# 31                    Posobiec states it is generated.                  NaN
# 32                Tagged by sharer as "Funny Deepfake"                  NaN
# ..                                                 ...                  ...
# 917                                                NaN                  NaN
# 925                                                NaN                  NaN
# 957                                                NaN                  NaN
# 958                                                NaN                  NaN
# 960                                                NaN                  NaN
#
#     sharer_faketype  external_verification  \
# 16             fake          verified_fake
# 18             fake          verified_fake
# 20   real_authentic          verified_fake
# 31             fake          verified_fake
# 32             fake  authenticity_disputed
# ..              ...                    ...
# 917            fake  authenticity_disputed
# 925         unclear          verified_fake
# 957         unclear          verified_fake
# 958            fake          verified_fake
# 960            fake  authenticity_disputed
#
#                                     links_verification  \
# 16   https://www.politico.eu/article/ai-photography...
# 18   https://apnews.com/article/fact-check-kamala-h...
# 20   Facebook flagged the video as an altered video...
# 31                                                 NaN
# 32   Could not find external source that confirmed ...
# ..                                                 ...
# 917                                                NaN
# 925  https://timesofindia.indiatimes.com/world/us/e...
# 957  https://www.news18.com/world/trump-takes-aim-a...
# 958  https://www.cbsnews.com/news/trump-shares-fake...
# 960                                                NaN
#
#                                          evidence_fake        watermark  \
# 16     Both Biden and Putins skin is extremely shiny.                no
# 18   Her mouth looks slightly distorted, and some o...               no
# 20   Harris' speech sounds unnaturally slurred and ...              yes
# 31   disjoint between AOC's mouth and words. Unnatu...  unclear_unknown
# 32   The mouth movements do not completely line up ...              yes
# ..                                                 ...              ...
# 917  There are display texts but they are not reada...               no
# 925          Faces are blurred and hands are deformed.               no
# 957  All the soldiers in the audience have almost t...               no
# 958  Her face is very airbrushed looking and the wh...               no
# 960                 Image is extremely smoothed over.                no
#
#       likes  views comments shares         original_source_name  \
# 16        1    219        1      1  Pablo Delcan and Midjourney
# 18       54   7852       12     22                          NaN
# 20   29.8K     NaN        4    43K                          NaN
# 31     6.1k   2.3M     1.4k   1.4k                Jack Posobiec
# 32      10K    NaN      934    NaN                   GamingHubz
# ..      ...    ...      ...    ...                          ...
# 917       4    206        1      0                  Bill DeMayo
# 925    908k  57.3M      33k   128k                 Donald Trump
# 957      19  1,873        2      5                 Donald Trump
# 958       0    140        0      0                          NaN
# 960       4    108        1      0                  Bill DeMayo
#
#     original_source_type                         original_source_actor_type  \
# 16            individual                                    unclear_unknown
# 18       unclear_unknown                                    unclear_unknown
# 20       unclear_unknown                                    unclear_unknown
# 31      individual,group  Private or Non-Governmental Organization,gover...
# 32       unclear_unknown                                    Unclear/unknown
# ..                   ...                                                ...
# 917           individual           Private or Non-Governmental Organization
# 925           individual                         Political Leader or Figure
# 957           individual                         Political Leader or Figure
# 958      unclear_unknown                                    Unclear/unknown
# 960           individual                                    Unclear/unknown
#
#       original_source_country  \
# 16             United States
# 18                         NA
# 20                         NA
# 31             United States
# 32                         NA
# ..                        ...
# 917  United States of America
# 925  United States of America
# 957  United States of America
# 958                        NA
# 960  United States of America
#
#                        comments_coding_original_source         sharer_name  \
# 16              I looked at Pablo Delcan's instagram.       Douglas Lucas
# 18   The original source is not named in the AP art...  Patrick Henningsen
# 20                                                 NaN     Layce Hale Holt
# 31                                        user profile      Jack Posobiec
# 32                                                 NaN          GamingHubz
# ..                                                 ...                 ...
# 917                                                NaN        @cattocrunch
# 925                                                NaN        Donald Trump
# 957                                                NaN           JereMemez
# 958  Could not find a true creator of the photo sin...    @YourMomsHo42215
# 960                                                NaN               Other
#
#     other_sharer_name sharer_username                        sharer_type  \
# 16                NaN             NaN                         individual
# 18                NaN             NaN        individual,high_impact_user
# 20                NaN             NaN                         individual
# 31                NaN             NaN  individual,group,high_impact_user
# 32                NaN             NaN                   non-identifiable
# ..                ...             ...                                ...
# 917               NaN             NaN                         individual
# 925               NaN             NaN                   high_impact_user
# 957               NaN      Jere_Memez                         individual
# 958               NaN             NaN                         individual
# 960           crumcho    @cattocrunch                         individual
#
#           sharer_job                                high_impact_comment  \
# 16             other  Writer and has a blog, but not necessarily a j...
# 18        journalist                                     162K followers
# 20       random_user                                                NaN
# 31       random_user                                               2.4M
# 32   unclear_unknown                                                NaN
# ..               ...                                                ...
# 917      random_user                                                NaN
# 925       politician                            102.2 million followers
# 957      random_user                                                NaN
# 958      random_user                                                NaN
# 960      random_user                                                NaN
#
#                sharer_country other_sharer_country      sharer_city  \
# 16   United States of America                  NaN          Seattle
# 18   United States of America                  NaN          Arizona
# 20   United States of America                  NaN       McMinville
# 31   United States of America                  NaN          unknown
# 32                   unknown                   NaN          unknown
# ..                        ...                  ...              ...
# 917                  unknown                   NaN          unknown
# 925  United States of America                  NaN  Washington D.C.
# 957                  unknown                   NaN          unknown
# 958                  unknown                    na          unknown
# 960                  unknown                   NaN          unknown
#
#     other_sharer_city              comments_sharer_coding  \
# 16                NaN                                 NaN
# 18                NaN                                 NaN
# 20                NaN                                 NaN
# 31                NaN  user profile, simple google search
# 32                NaN                                 NaN
# ..                ...                                 ...
# 917               NaN                                 NaN
# 925               NaN                                 NaN
# 957               NaN                                 NaN
# 958               NaN                                 NaN
# 960               NaN                                 NaN
#
#                   target_name           target_one_name target_one_sentiment  \
# 16   Joe Biden,Vladimir Putin                 Joe Biden             Positive
# 18             Kamala Harris              Kamala Harris             Negative
# 20             Kamala Harris              Kamala Harris             Negative
# 31   Alexandria Ocasio-Cortez  Alexandria Ocasio-Cortez              Neutral
# 32             Tucker Carlson            Tucker Carlson              Neutral
# ..                        ...                       ...                  ...
# 917             Donald Trump               Donald Trump              Neutral
# 925   Donald Trump ,Elon Musk              Donald Trump             Positive
# 957            Kamala Harris              Kamala Harris             Negative
# 958                       NaN              Taylor Swift              Neutral
# 960             Donald Trump               Donald Trump             Negative
#
#     target_one_type_macro target_one_type_micro        target_one_country  \
# 16             individual            politician  United States of America
# 18             individual            politician  United States of America
# 20             individual            politician  United States of America
# 31             individual            politician  United States of America
# 32             individual            journalist  United States of America
# ..                    ...                   ...                       ...
# 917            individual            politician  United States of America
# 925            individual            politician  United States of America
# 957            individual            politician  United States of America
# 958            individual         public_figure  United States of America
# 960            individual            politician  United States of America
#
#     target_two_name target_two_sentiment target_two_type_macro  \
# 16   Vladimir Putin             Positive            individual
# 18              NaN                  NaN                   NaN
# 20              NaN                  NaN                   NaN
# 31              NaN                  NaN                   NaN
# 32              NaN                  NaN                   NaN
# ..              ...                  ...                   ...
# 917             NaN                  NaN                   NaN
# 925       Elon Musk             Positive            individual
# 957             NaN                  NaN                   NaN
# 958             NaN                  NaN                   NaN
# 960             NaN                  NaN                   NaN
#
#     target_two_type_micro        target_two_country target_three_name  \
# 16             politician                    Russia               NaN
# 18                    NaN                       NaN               NaN
# 20                    NaN                       NaN               NaN
# 31                    NaN                       NaN               NaN
# 32                    NaN                       NaN               NaN
# ..                    ...                       ...               ...
# 917                   NaN                       NaN               NaN
# 925         public_figure  United States of America               NaN
# 957                   NaN                       NaN               NaN
# 958                   NaN                       NaN               NaN
# 960                   NaN                       NaN               NaN
#
#     target_three_sentiment target_three_type_macro target_three_type_micro  \
# 16                     NaN                     NaN                     NaN
# 18                     NaN                     NaN                     NaN
# 20                     NaN                     NaN                     NaN
# 31                     NaN                     NaN                     NaN
# 32                     NaN                     NaN                     NaN
# ..                     ...                     ...                     ...
# 917                    NaN                     NaN                     NaN
# 925                    NaN                     NaN                     NaN
# 957                    NaN                     NaN                     NaN
# 958                    NaN                     NaN                     NaN
# 960                    NaN                     NaN                     NaN
#
#     target_three_country target_type_macro target_type_micro  \
# 16                   NaN        individual        politician
# 18                   NaN        individual        politician
# 20                   NaN        individual        politician
# 31                   NaN        individual        politician
# 32                   NaN        individual     public_figure
# ..                   ...               ...               ...
# 917                  NaN               NaN               NaN
# 925                  NaN               NaN               NaN
# 957                  NaN        individual        politician
# 958                  NaN               NaN               NaN
# 960                  NaN               NaN               NaN
#
#                       target_country          comments_target_coding  \
# 16   United States of America,Russia                             NaN
# 18          United States of America                             NaN
# 20          United States of America                             NaN
# 31          United States of America  went through responses briefly
# 32          United States of America                             NaN
# ..                               ...                             ...
# 917                              NaN                             NaN
# 925                              NaN                             NaN
# 957         United States of America                             NaN
# 958                              NaN                             NaN
# 960                              NaN                             NaN
#
#                               deepfake_content_depicts  \
# 16     government_legal_system,international_relations
# 18                             government_legal_system
# 20                             government_legal_system
# 31   scandal,deepfake_regulation,government_legal_s...
# 32                                 deepfake_regulation
# ..                                                 ...
# 917                                           election
# 925                                           election
# 957                                           election
# 958                       election,deepfake_regulation
# 960                                           election
#
#                harm_depicted  \
# 16          non-identifiable
# 18                     other
# 20                     other
# 31   discrimination,violence
# 32          non-identifiable
# ..                       ...
# 917         non-identifiable
# 925         non-identifiable
# 957         non-identifiable
# 958       other,human_rights
# 960         non-identifiable
#
#                                 comments_content_topic  \
# 16                                                 NaN
# 18   The harms of the deepfake are more related to ...
# 20   The deepfake pertains to harms related to Kama...
# 31   ukraine war = violence, discrimination = minor...
# 32                                                 NaN
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                                NaN
# 958                                                NaN
# 960                                                NaN
#
#                                   social_policy_sector  \
# 16                         military_public_safety_govt
# 18                         military_public_safety_govt
# 20                         military_public_safety_govt
# 31   military_public_safety_govt,broadcasting_media...
# 32   arts_sports_leisure_travel_lifestyle,consumer_...
# ..                                                 ...
# 917                        military_public_safety_govt
# 925                        military_public_safety_govt
# 957                        military_public_safety_govt
# 958  military_public_safety_govt,broadcasting_media...
# 960                        military_public_safety_govt
#
#                          comments_social_policy_sector  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 31   media including deepfake creation and display ...
# 32                                                 NaN
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                                NaN
# 958                                                NaN
# 960                                                NaN
#
#                                       context_deepfake  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 31                                  ukraine-russia war
# 32                                                 NaN
# ..                                                 ...
# 917  This original post is from a reply to a post m...
# 925  This was posted during the 2024 presidential e...
# 957  This was in the midst of election campaigning ...
# 958  Donald Trump was quite frequently posting AI c...
# 960  This original post is from a reply to a post m...
#
#                                   text_around_deepfake  \
# 16   AI and the end of photographic truth? Deceptiv...
# 18   ⭕️ Granted, this must be a deep fake, but rega...
# 20   "Our VP: 'I can only hit this bong 1 more time...
# 31   "The deepfake that Jack Posobiec made of Presi...
# 32   ChatGPT wrote ALL the words coming out of this...
# ..                                                 ...
# 917  The caption says: "holy shit man look at these...
# 925                                               NA\n
# 957                                                NaN
# 958  Sharer: "Imagine the group that says “Kamala h...
# 960  The caption says: "holy shit man look at these...
#
#                            harm_evidence  \
# 16                political_interference
# 18                      non_identifiable
# 20                                 other
# 31                political_interference
# 32                      non_identifiable
# ..                                   ...
# 917               political_interference
# 925                     non_identifiable
# 957               political_interference
# 958  political_interference,human_rights
# 960               political_interference
#
#                                 comments_harms_context  \
# 16                                                 NaN
# 18   The harm is to the vice president's credibilit...
# 20                                                 NaN
# 31   possible distrust/apprehension about governmen...
# 32                                                 NaN
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                                NaN
# 958  I put human rights, because it is using a publ...
# 960                                                NaN
#
#                                     communication_goal  \
# 16                                           education
# 18                satire,entertainment,harm_reputation
# 20                satire,entertainment,harm_reputation
# 31   entertainment,harm_political_interference,acti...
# 32   satire,entertainment,harm_emotional_psychological
# ..                                                 ...
# 917                               satire,entertainment
# 925                               entertainment,satire
# 957  harm_political_interference,false_info,harm_re...
# 958        harm_reputation,harm_political_interference
# 960                               satire,entertainment
#
#                            comments_communication_goal  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 31   seemed in-between activism and slandering AOC'...
# 32                                                 NaN
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                                NaN
# 958                                                NaN
# 960                                                NaN
#
#                         core_frame  \
# 16                  human_interest
# 18                  human_interest
# 20                  human_interest
# 31         responsibility,conflict
# 32                  human_interest
# ..                             ...
# 917                 human_interest
# 925                 human_interest
# 957                 human_interest
# 958  human_interest,responsibility
# 960                 human_interest
#
#                                comments_core_frame  \
# 16                                             NaN
# 18                                             NaN
# 20                                             NaN
# 31   based off context in user's profile and video
# 32                                             NaN
# ..                                             ...
# 917                                            NaN
# 925                                            NaN
# 957                                            NaN
# 958                                            NaN
# 960                                            NaN
#
#                                                   hero  \
# 16                                               Biden
# 18   A leader who sounds smart and capable during s...
# 20   People expect that a VP can communicate with c...
# 31     Poso's supposters, those who share his ideology
# 32                                                 NaN
# ..                                                 ...
# 917                                       Donald Trump
# 925                         Donald Trump and Elon Musk
# 957                                                NaN
# 958                                            unknown
# 960                                                NaN
#
#                                                villain  \
# 16                                               Putin
# 18   Kamala Harris rambling and not making sense du...
# 20     Online users believe that Harris is a rambler.
# 31   AOC, and other related gov. officials who shar...
# 32                          ChatGPT and other AI tech
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                      Kamala Harris
# 958                                       Donald Trump
# 960                                       Donald Trump
#
#                                                   plot  \
# 16                            Putin and Biden hugging
# 18   Kamala's speech does not make sense, which lea...
# 20   Kamala Harris is shown to be giving a speech t...
# 31   Biden and AOC do not understand how to priorit...
# 32   AI programs give people the ability to create ...
# ..                                                 ...
# 917  The post suggests that while some people are c...
# 925                   Trump and Musk dancing together
# 957  If Harris is elected president, she will turn ...
# 958  Unclear, but demonstrates that Donald Trump is...
# 960  The post suggests that while some people are c...
#
#                                                  moral  \
# 16             U.S. and Russian leaders can get along
# 18   Kamala Harris's credibility as VP should be qu...
# 20   Kamala Harris is portrayed as being unable to ...
# 31   we must take a stand against their choices to ...
# 32   AI has progressed more than a lot of people re...
# ..                                                 ...
# 917  AI is being used by politicians to manipulate ...
# 925  Trump and Musk work well together, so vote for...
# 957                        Vote for Trump, not Harris
# 958  AI can be used but it is important that it mus...
# 960  AI is being used by politicians to manipulate ...
#
#     comments_policy_narrative Validated            domain    year
# 16                        NaN       NaN       twitter.com  2023.0
# 18                        NaN       NaN       twitter.com  2023.0
# 20                        NaN       NaN  www.facebook.com  2023.0
# 31   fairly explicitly stated       NaN       twitter.com  2023.0
# 32                        NaN       NaN    www.reddit.com  2023.0
# ..                        ...       ...               ...     ...
# 917                       NaN       NaN             x.com  2024.0
# 925                       NaN       NaN             x.com  2024.0
# 957                       NaN   checked             x.com  2024.0
# 958                       NaN       NaN             x.com  2024.0
# 960                       NaN   checked             x.com  2024.0
#
# [340 rows x 81 columns]

# %% [markdown]
# ### 2. 2023-2024 analysis of deepfake images/videos, regardless of verification

# %%
df2 = df[
    (df['year'].isin([2023, 2024])) & 
    (df['type'] == 'deepfake') &       
    (df['file'].notna())            
]

# %%
print(df2.shape)
display(df2)
# Out:
# (714, 81)
#      incident_id report_id Validated By Title  date_coded  \
# 16           203        17          NaN   NaN  2024-02-12
# 18           186        18          NaN   NaN  2024-02-04
# 20           187        19          NaN   NaN  2024-02-05
# 22           188        20          NaN   NaN  2024-02-05
# 31           201        25          NaN   NaN  2024-02-09
# ..           ...       ...          ...   ...         ...
# 971         1058       460          NaN   NaN  2025-03-06
# 972         1059       599          NaN   NaN  2025-03-06
# 973         1060       757          NaN   NaN  2025-03-06
# 974         1061       758          NaN   NaN  2025-03-06
# 975         1062       759          NaN   NaN  2025-03-06
#
#                                                    url  \
# 16   https://twitter.com/DouglasLucas/status/171631...
# 18   https://twitter.com/21WIRE/status/165300993699...
# 20       https://www.facebook.com/reel/894486844951526
# 22   https://twitter.com/JebraFaushay/status/165937...
# 31   https://twitter.com/JackPosobiec/status/163383...
# ..                                                 ...
# 971  https://x.com/PlanetOfMemes/status/18240700394...
# 972  https://x.com/KryptoKarma2024/status/182516139...
# 973  https://x.com/Trump_History45/status/183139475...
# 974  https://x.com/Trump_History45/status/182900803...
# 975  https://x.com/Trump_History45/status/182891374...
#
#                                                   file  \
# 16   Screenshot 2024-02-12 at 12.47.24 PM.png (http...
# 18   "Patrick Henningsen on X_ _⭕️ Granted, this mu...
# 20   deepfake 19.html (https://v5.airtableuserconte...
# 22   Deepfake 20.html (https://v5.airtableuserconte...
# 31   Screenshot 2024-02-09 134519.png (https://v5.a...
# ..                                                 ...
# 971  460.png (https://v5.airtableusercontent.com/v3...
# 972  599.png (https://v5.airtableusercontent.com/v3...
# 973  pdid 757.jpg (https://v5.airtableusercontent.c...
# 974  pdid 758.jpg (https://v5.airtableusercontent.c...
# 975  pdid 759.jpg (https://v5.airtableusercontent.c...
#
#                                             screenshot date_posted format  \
# 16                                                 NaN  2023-10-23  image
# 18                                                 NaN  2023-05-01  video
# 20                                                 NaN  2023-05-03  video
# 22                                                 NaN  2023-05-18  video
# 31                                                 NaN  2023-03-09  video
# ..                                                 ...         ...    ...
# 971  Screenshot 2025-03-05 at 8.45.11 PM.png (https...  2024-08-15  image
# 972  Screenshot 2025-03-06 at 3.01.04 PM.png (https...  2024-08-18  image
# 973  Screen Shot 2025-03-06 at 3.17.43 PM.png (http...  2024-09-04  image
# 974  Screen Shot 2025-03-06 at 3.37.57 PM.png (http...  2024-08-29  image
# 975  Screen Shot 2025-03-06 at 3.54.58 PM.png (http...  2024-08-28  image
#
#                                             transcript  \
# 16                                                 NaN
# 18   "Today is today, and yesterday was today yeste...
# 20   “Today is today, and yesterday is today yester...
# 22   "Excuse me, excuse me. I need everyone in the ...
# 31   I'll tell you something the deepfake that Jack...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
#
#                                        summary_content      type  \
# 16   Two polaroid photographs, the one one the righ...  deepfake
# 18   Kamala Harris is speaking at a rally and her s...  deepfake
# 20   The sharer posted a video showing her reacting...  deepfake
# 22   The video shows Donald Trump, Mike Pence, and ...  deepfake
# 31   AOC announcing her opinions with regards to ho...  deepfake
# ..                                                 ...       ...
# 971  Donald Trump and Elon Musk are sitting, talkin...  deepfake
# 972  Donald Trump is riding a horse with eagle wing...  deepfake
# 973  It is a picture of Kamala Harris shaking hands...  deepfake
# 974  It is an image of Barack Obama's face in front...  deepfake
# 975  It is an image of Donald Trump dressed up as t...  deepfake
#
#                                           comment_type HiveModeration_Score  \
# 16   The caption of the post states that the photo ...             100% AI
# 18   AP News Article identifies the video as a deep...                  NaN
# 20   The video of Kamala Harris has been confirmed ...                  NaN
# 22   The video looks extremely unrealistic, but the...                  NaN
# 31                    Posobiec states it is generated.                  NaN
# ..                                                 ...                  ...
# 971                                                NaN                  NaN
# 972                                                NaN                  NaN
# 973                                                NaN                  NaN
# 974                                                NaN                  NaN
# 975                                                NaN                  NaN
#
#     sharer_faketype external_verification  \
# 16             fake         verified_fake
# 18             fake         verified_fake
# 20   real_authentic         verified_fake
# 22          unclear               unknown
# 31             fake         verified_fake
# ..              ...                   ...
# 971         unclear               unknown
# 972         unclear               unknown
# 973         unclear               unknown
# 974         unclear               unknown
# 975         unclear               unknown
#
#                                     links_verification  \
# 16   https://www.politico.eu/article/ai-photography...
# 18   https://apnews.com/article/fact-check-kamala-h...
# 20   Facebook flagged the video as an altered video...
# 22   External verification of the video's authentic...
# 31                                                 NaN
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973  Image clearly shows her shaking hands with an ...
# 974  Reverse google image searched the picture and ...
# 975  I tried reverse google image searching and cou...
#
#                                          evidence_fake        watermark  \
# 16     Both Biden and Putins skin is extremely shiny.                no
# 18   Her mouth looks slightly distorted, and some o...               no
# 20   Harris' speech sounds unnaturally slurred and ...              yes
# 22   The figures in the video look heavily unrealis...               no
# 31   disjoint between AOC's mouth and words. Unnatu...  unclear_unknown
# ..                                                 ...              ...
# 971                         Trump's hands are deformed               no
# 972  The horse is deformed and Trump has eagle wings.                no
# 973  Her facial features do seem dimmed down or les...               no
# 974  Airbrushed face, clearly digitally applied red...               no
# 975  Image of the body in this picture is the same ...               no
#
#       likes        views comments shares         original_source_name  \
# 16        1          219        1      1  Pablo Delcan and Midjourney
# 18       54         7852       12     22                          NaN
# 20   29.8K           NaN        4    43K                          NaN
# 22       55       14.3K        25     10                          NaN
# 31     6.1k         2.3M     1.4k   1.4k                Jack Posobiec
# ..      ...          ...      ...    ...                          ...
# 971     687        92.9k       16     33                          NaN
# 972       5          827        0      1                          NaN
# 973     598        34.5K       44     72                          NaN
# 974     260  16.2K views       32     29                          NaN
# 975     805    46K views       47     90                          NaN
#
#     original_source_type                         original_source_actor_type  \
# 16            individual                                    unclear_unknown
# 18       unclear_unknown                                    unclear_unknown
# 20       unclear_unknown                                    unclear_unknown
# 22       unclear_unknown                                    unclear_unknown
# 31      individual,group  Private or Non-Governmental Organization,gover...
# ..                   ...                                                ...
# 971      unclear_unknown                                    Unclear/unknown
# 972      unclear_unknown                                    Unclear/unknown
# 973      unclear_unknown                                    Unclear/unknown
# 974      unclear_unknown                                    Unclear/unknown
# 975      unclear_unknown                                    Unclear/unknown
#
#     original_source_country  \
# 16           United States
# 18                       NA
# 20                       NA
# 22                       NA
# 31           United States
# ..                      ...
# 971                      NA
# 972                      NA
# 973                      NA
# 974                      NA
# 975                      NA
#
#                        comments_coding_original_source         sharer_name  \
# 16              I looked at Pablo Delcan's instagram.       Douglas Lucas
# 18   The original source is not named in the AP art...  Patrick Henningsen
# 20                                                 NaN     Layce Hale Holt
# 22                                                 NaN   Dr. Jebra Faushay
# 31                                        user profile      Jack Posobiec
# ..                                                 ...                 ...
# 971                                                NaN     Planet Of Memes
# 972                                                NaN               Other
# 973                                                NaN       Trump History
# 974                                                NaN       Trump History
# 975                                                NaN       Trump History
#
#     other_sharer_name   sharer_username                        sharer_type  \
# 16                NaN               NaN                         individual
# 18                NaN               NaN        individual,high_impact_user
# 20                NaN               NaN                         individual
# 22                NaN               NaN        individual,high_impact_user
# 31                NaN               NaN  individual,group,high_impact_user
# ..                ...               ...                                ...
# 971               NaN   @PlanetOfMemes                    high_impact_user
# 972     Krypto Karma   @KryptoKarma2024                   non-identifiable
# 973               NaN   Trump_History45        individual,high_impact_user
# 974               NaN   Trump_History45        individual,high_impact_user
# 975               NaN   Trump_History45        individual,high_impact_user
#
#               sharer_job                                high_impact_comment  \
# 16                 other  Writer and has a blog, but not necessarily a j...
# 18            journalist                                     162K followers
# 20           random_user                                                NaN
# 22   researcher_academic                                   146.6K followers
# 31           random_user                                               2.4M
# ..                   ...                                                ...
# 971          random_user                                                NaN
# 972          random_user                                                NaN
# 973          random_user                                   136.6K followers
# 974          random_user                                   136.6K followers
# 975          random_user                                  136.6 K followers
#
#                sharer_country other_sharer_country sharer_city  \
# 16   United States of America                  NaN     Seattle
# 18   United States of America                  NaN     Arizona
# 20   United States of America                  NaN  McMinville
# 22   United States of America                  NaN  California
# 31   United States of America                  NaN     unknown
# ..                        ...                  ...         ...
# 971                  unknown                   NaN     unknown
# 972                  unknown                   NaN     unknown
# 973  United States of America                   na     unknown
# 974  United States of America                   na     unknown
# 975  United States of America                   na     unknown
#
#     other_sharer_city              comments_sharer_coding  \
# 16                NaN                                 NaN
# 18                NaN                                 NaN
# 20                NaN                                 NaN
# 22                NaN                                 NaN
# 31                NaN  user profile, simple google search
# ..                ...                                 ...
# 971               NaN                                 NaN
# 972               NaN                                 NaN
# 973               NaN                                 NaN
# 974               NaN                                 NaN
# 975               NaN                                 NaN
#
#                                    target_name           target_one_name  \
# 16                    Joe Biden,Vladimir Putin                 Joe Biden
# 18                              Kamala Harris              Kamala Harris
# 20                              Kamala Harris              Kamala Harris
# 22   Donald Trump ,Mike Pence ,Mitch McConnell              Donald Trump
# 31                    Alexandria Ocasio-Cortez  Alexandria Ocasio-Cortez
# ..                                         ...                       ...
# 971                                        NaN              Donald Trump
# 972                                        NaN              Donald Trump
# 973                                        NaN             Kamala Harris
# 974                                        NaN              Barack Obama
# 975                                        NaN              Donald Trump
#
#     target_one_sentiment target_one_type_macro target_one_type_micro  \
# 16              Positive            individual            politician
# 18              Negative            individual            politician
# 20              Negative            individual            politician
# 22               Neutral            individual            politician
# 31               Neutral            individual            politician
# ..                   ...                   ...                   ...
# 971              Neutral            individual            politician
# 972             Positive            individual            politician
# 973             Negative            individual            politician
# 974             Negative            individual            politician
# 975             Positive            individual            politician
#
#            target_one_country target_two_name target_two_sentiment  \
# 16   United States of America  Vladimir Putin             Positive
# 18   United States of America             NaN                  NaN
# 20   United States of America             NaN                  NaN
# 22   United States of America      Mike Pence              Neutral
# 31   United States of America             NaN                  NaN
# ..                        ...             ...                  ...
# 971  United States of America       Elon Musk              Neutral
# 972  United States of America             NaN                  NaN
# 973  United States of America             NaN                  NaN
# 974  United States of America             NaN                  NaN
# 975  United States of America             NaN                  NaN
#
#     target_two_type_macro target_two_type_micro        target_two_country  \
# 16             individual            politician                    Russia
# 18                    NaN                   NaN                       NaN
# 20                    NaN                   NaN                       NaN
# 22             individual            politician  United States of America
# 31                    NaN                   NaN                       NaN
# ..                    ...                   ...                       ...
# 971            individual         public_figure  United States of America
# 972                   NaN                   NaN                       NaN
# 973                   NaN                   NaN                       NaN
# 974                   NaN                   NaN                       NaN
# 975                   NaN                   NaN                       NaN
#
#     target_three_name target_three_sentiment target_three_type_macro  \
# 16                NaN                    NaN                     NaN
# 18                NaN                    NaN                     NaN
# 20                NaN                    NaN                     NaN
# 22    Mitch McConnell                Neutral              individual
# 31                NaN                    NaN                     NaN
# ..                ...                    ...                     ...
# 971               NaN                    NaN                     NaN
# 972               NaN                    NaN                     NaN
# 973               NaN                    NaN                     NaN
# 974               NaN                    NaN                     NaN
# 975               NaN                    NaN                     NaN
#
#     target_three_type_micro      target_three_country target_type_macro  \
# 16                      NaN                       NaN        individual
# 18                      NaN                       NaN        individual
# 20                      NaN                       NaN        individual
# 22               politician  United States of America             group
# 31                      NaN                       NaN        individual
# ..                      ...                       ...               ...
# 971                     NaN                       NaN               NaN
# 972                     NaN                       NaN               NaN
# 973                     NaN                       NaN               NaN
# 974                     NaN                       NaN               NaN
# 975                     NaN                       NaN               NaN
#
#     target_type_micro                   target_country  \
# 16         politician  United States of America,Russia
# 18         politician         United States of America
# 20         politician         United States of America
# 22         politician         United States of America
# 31         politician         United States of America
# ..                ...                              ...
# 971               NaN                              NaN
# 972               NaN                              NaN
# 973               NaN                              NaN
# 974               NaN                              NaN
# 975               NaN                              NaN
#
#              comments_target_coding  \
# 16                              NaN
# 18                              NaN
# 20                              NaN
# 22                              NaN
# 31   went through responses briefly
# ..                              ...
# 971                             NaN
# 972                             NaN
# 973                             NaN
# 974                             NaN
# 975                             NaN
#
#                               deepfake_content_depicts  \
# 16     government_legal_system,international_relations
# 18                             government_legal_system
# 20                             government_legal_system
# 22                                             scandal
# 31   scandal,deepfake_regulation,government_legal_s...
# ..                                                 ...
# 971                                           election
# 972                                           election
# 973                   election,international_relations
# 974                                 marginalized_group
# 975                        election,marginalized_group
#
#                        harm_depicted  \
# 16                  non-identifiable
# 18                             other
# 20                             other
# 22              discrimination,other
# 31           discrimination,violence
# ..                               ...
# 971                 non-identifiable
# 972                 non-identifiable
# 973                     human_rights
# 974      human_rights,discrimination
# 975  non-identifiable,discrimination
#
#                                 comments_content_topic  \
# 16                                                 NaN
# 18   The harms of the deepfake are more related to ...
# 20   The deepfake pertains to harms related to Kama...
# 22                                                 NaN
# 31   ukraine war = violence, discrimination = minor...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974  User implies a negative connotation towards in...
# 975                                                NaN
#
#                                   social_policy_sector  \
# 16                         military_public_safety_govt
# 18                         military_public_safety_govt
# 20                         military_public_safety_govt
# 22   military_public_safety_govt,arts_sports_leisur...
# 31   military_public_safety_govt,broadcasting_media...
# ..                                                 ...
# 971                        military_public_safety_govt
# 972                        military_public_safety_govt
# 973  broadcasting_media_production,military_public_...
# 974                broadcasting_media_production,other
# 975  military_public_safety_govt,broadcasting_media...
#
#                          comments_social_policy_sector  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 22                                                 NaN
# 31   media including deepfake creation and display ...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
#
#                                       context_deepfake  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 22   Many Republican states have introduced legisla...
# 31                                  ukraine-russia war
# ..                                                 ...
# 971  This is a post underneath Trump's post of him ...
# 972      Posted during the 2024 presidential election
# 973  This image was posted in the midst of election...
# 974  It implies people trying to push the narrative...
# 975  Based on the caption, this post makes referenc...
#
#                                   text_around_deepfake  \
# 16   AI and the end of photographic truth? Deceptiv...
# 18   ⭕️ Granted, this must be a deep fake, but rega...
# 20   "Our VP: 'I can only hit this bong 1 more time...
# 22   Is this real? I feel like it might be a deep f...
# 31   "The deepfake that Jack Posobiec made of Presi...
# ..                                                 ...
# 971     The caption says "Let's do some weekly spaces"
# 972  The caption says "@realDonaldTrump\n $RDT CTO ...
# 973  A young Kamala Harris shaking hands with commu...
# 974  Why is Barack Obama afraid to come out of the ...
# 975  No Pope has ever been tougher on illegal immig...
#
#                              harm_evidence  \
# 16                  political_interference
# 18                        non_identifiable
# 20                                   other
# 22                                   other
# 31                  political_interference
# ..                                     ...
# 971                       non_identifiable
# 972                 political_interference
# 973                 political_interference
# 974            discrimination,human_rights
# 975  political_interference,discrimination
#
#                                 comments_harms_context  \
# 16                                                 NaN
# 18   The harm is to the vice president's credibilit...
# 20                                                 NaN
# 22   The harm caused would be to the Republican pol...
# 31   possible distrust/apprehension about governmen...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
#
#                                     communication_goal  \
# 16                                           education
# 18                satire,entertainment,harm_reputation
# 20                satire,entertainment,harm_reputation
# 22                satire,entertainment,harm_reputation
# 31   entertainment,harm_political_interference,acti...
# ..                                                 ...
# 971                     boost_reputation,entertainment
# 972       boost_reputation,harm_political_interference
# 973  false_info,harm_political_interference,harm_re...
# 974                         false_info,harm_reputation
# 975                            boost_reputation,satire
#
#                            comments_communication_goal  \
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 22                                                 NaN
# 31   seemed in-between activism and slandering AOC'...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
#
#                         core_frame  \
# 16                  human_interest
# 18                  human_interest
# 20                  human_interest
# 22         conflict,human_interest
# 31         responsibility,conflict
# ..                             ...
# 971                 human_interest
# 972                 human_interest
# 973  human_interest,responsibility
# 974                 human_interest
# 975  human_interest,responsibility
#
#                                comments_core_frame  \
# 16                                             NaN
# 18                                             NaN
# 20                                             NaN
# 22                                             NaN
# 31   based off context in user's profile and video
# ..                                             ...
# 971                                            NaN
# 972                                            NaN
# 973                                            NaN
# 974                                            NaN
# 975                                            NaN
#
#                                                   hero  \
# 16                                               Biden
# 18   A leader who sounds smart and capable during s...
# 20   People expect that a VP can communicate with c...
# 22   The freedom for Trump and his squad to dress i...
# 31     Poso's supposters, those who share his ideology
# ..                                                 ...
# 971                         Donald Trump and Elon Musk
# 972                                      Donald Trump
# 973                                       Donald Trump
# 974                                            unclear
# 975                                       Donald Trump
#
#                                                villain  \
# 16                                               Putin
# 18   Kamala Harris rambling and not making sense du...
# 20     Online users believe that Harris is a rambler.
# 22                   Republicans who want to ban drag.
# 31   AOC, and other related gov. officials who shar...
# ..                                                 ...
# 971                                                NaN
# 972                                     Kamala Harris
# 973                                      Kamala Harris
# 974                                       Barack Obama
# 975                                 Illegal Immigrants
#
#                                                   plot  \
# 16                            Putin and Biden hugging
# 18   Kamala's speech does not make sense, which lea...
# 20   Kamala Harris is shown to be giving a speech t...
# 22   Republicans want to ban drag, but Donald Trump...
# 31   Biden and AOC do not understand how to priorit...
# ..                                                 ...
# 971                        Trump and Musk are friends
# 972                     The 2024 presidential election
# 973  Kamala Harris wants to create something like a...
# 974  Obama only legalized gay marriage for his own ...
# 975  Donald Trump must prevent illegal immigration ...
#
#                                                  moral  \
# 16             U.S. and Russian leaders can get along
# 18   Kamala Harris's credibility as VP should be qu...
# 20   Kamala Harris is portrayed as being unable to ...
# 22   Republicans should stop calling for drag to be...
# 31   we must take a stand against their choices to ...
# ..                                                 ...
# 971        Donald Trump and Elon Musk are a good team
# 972                             Vote for Donald Trump
# 973  Vote for a president who will keep government ...
# 974  Don't support someone who won't openly be hone...
# 975  Donald Trump will allow Americans to maintain ...
#
#     comments_policy_narrative Validated            domain    year
# 16                        NaN       NaN       twitter.com  2023.0
# 18                        NaN       NaN       twitter.com  2023.0
# 20                        NaN       NaN  www.facebook.com  2023.0
# 22                        NaN       NaN       twitter.com  2023.0
# 31   fairly explicitly stated       NaN       twitter.com  2023.0
# ..                        ...       ...               ...     ...
# 971                       NaN       NaN             x.com  2024.0
# 972                       NaN       NaN             x.com  2024.0
# 973                       NaN       NaN             x.com  2024.0
# 974                       NaN       NaN             x.com  2024.0
# 975                       NaN       NaN             x.com  2024.0
#
# [714 rows x 81 columns]

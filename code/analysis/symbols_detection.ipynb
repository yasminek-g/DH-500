# %% [markdown]
# # Symbol Detection via Reference Image Matching using YOLO and CLIP
#
# This notebook implements an image-based symbolic detection pipeline that combines:
#
# - **YOLOv8n** for proposing visual regions of interest.
# - **CLIP (ViT-L/14)** for computing visual similarity between cropped regions and a set of manually curated **reference images** of known symbols.
#
#
# ## Initial Approach: Grounding DINO
#
# The first method tested was Grounding DINO, a state-of-the-art object detection model. Despite its strong capabilities in zero-shot detection, it presented two key limitations:
#
# - **Computational Cost**: The model was too heavy for large-scale processing, especially with high-resolution inputs and multiple prompts.
# - **Low Localization Precision**: Even when detections were returned, the bounding boxes were often imprecise or included irrelevant parts of the image.
#
# Due to these constraints, the Grounding DINO pipeline was ultimately discarded in favor of a lighter and more controllable approach.
#
# ## Pipeline Overview
# 1. **Reference Symbol Embedding**:
#    - All images in the  are loaded and preprocessed.
#    - CLIP encodes these into normalized feature vectors (`ref_feats`), forming the semantic basis for comparison.
#
# 2. **Target Image Processing**:
#    - For each image YOLOv8 is used to extract bounding boxes.
#    - Each region is cropped, slightly padded, and passed through CLIP to compute a feature vector.
#
# 3. **Similarity Computation**:
#    - The cosine similarity between each cropped region and all reference vectors is computed.
#    - For each image, we retain the **mean and max similarity** across all regions.
#
# 4. **Results Summary**:
#    - For each image, we report:
#      - Filename
#      - Number of regions processed
#      - Max similarity to any reference symbol
#      - Mean similarity across all regions
#
# ## Special Case: Communist Symbol Detection
#
# A specific focus was given to the **communist symbol**, which was included in a real image (e.g. hammer and sickle).
#
# This strategy was adopted because:
#
# - **Prompt-based CLIP detection** (e.g. using `"communist symbol"` as a label) proved ambiguous and inconsistent.
# - The symbol shows **high intra-class variation** and appears in noisy or partial contexts (e.g. small red stars, stylized icons, flags).
#
# ### Why the Reference Approach Works Better
#
# - **Visual anchoring**: Matching against real examples allows CLIP to recognize symbols regardless of their semantic ambiguity or lack of textual training examples.
# - **More robust to distortion**: It handles rotated, stylized, or partially visible symbols better than relying on caption alignment.
#
# ### Thresholding & Interpretation
#
# - **High max similarity (>0.9)** generally indicates confident detection.
# - **Mean similarity** helps assess the overall symbolic content in an image.
#
# ## Conclusion
#
# This refined pipeline using YOLO for spatial localization and CLIP for reference-based similarity achieves robust detection of complex visual symbols in political or social imagery—especially where prompt-based zero-shot methods fail.

# %%
import os
import torch
import clip
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torchvision.transforms as T
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Load reference symbol
ref_image = preprocess(Image.open("Unknown.jpeg")).unsqueeze(0).to(device)
with torch.no_grad():
    ref_feat = model.encode_image(ref_image)
    ref_feat /= ref_feat.norm(dim=-1, keepdim=True)

# Load target image
target_pil = Image.open("/home/vmeroni/data/images/525.png").convert("RGB")
target_image = preprocess(target_pil).unsqueeze(0).to(device)

window_size = 128
stride = 64

fig, ax = plt.subplots(1)
ax.imshow(target_pil)

W, H = target_pil.size  # Image width and height
boxes_detected = []

# Store all "good" bounding boxes
good_boxes = []

# Sliding window across the image
for y in range(0, H - window_size + 1, stride):
    for x in range(0, W - window_size + 1, stride):
        crop = target_pil.crop((x, y, x + window_size, y + window_size))
        proc_crop = preprocess(crop).unsqueeze(0).to(device)

        with torch.no_grad():
            feat = model.encode_image(proc_crop)
            feat /= feat.norm(dim=-1, keepdim=True)
            sim = (feat @ ref_feat.T).item()

        if sim > 0.85:
            good_boxes.append((x, y, x + window_size, y + window_size))

# If high-confidence boxes were found
if good_boxes:
    good_boxes = np.array(good_boxes)
    x_min = int(good_boxes[:, 0].min())
    y_min = int(good_boxes[:, 1].min())
    x_max = int(good_boxes[:, 2].max())
    y_max = int(good_boxes[:, 3].max())

    # Show image with unified bounding box
    fig, ax = plt.subplots(1)
    ax.imshow(target_pil)
    ax.add_patch(patches.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                                   linewidth=3, edgecolor='red', facecolor='none'))
    ax.set_title("Detected political symbol")
    plt.axis('off')
    plt.show()
else:
    print("No symbol detected with sufficient confidence.")
# Out:
# /home/vmeroni/lab/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
from ultralytics import YOLO
from PIL import Image
import torch
import clip
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# === SETUP ===
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-B/32", device=device)

text_prompts = ["american", "political logo", "flag", "nothing important"]
text_tokens = clip.tokenize(text_prompts).to(device)
with torch.no_grad():
    text_features = clip_model.encode_text(text_tokens)
    text_features /= text_features.norm(dim=-1, keepdim=True)

# === LOAD IMAGE + YOLO ===
image_path = "/home/vmeroni/data/images/525.png"
image = Image.open(image_path).convert("RGB")
yolo_model = YOLO("yolov8n.pt")
results = yolo_model(image_path)
r = results[0]

# === DETECTION ===
fig, ax = plt.subplots(1)
ax.imshow(image)
symbols_detected = []

for box in r.boxes.xyxy:
    x1, y1, x2, y2 = map(int, box.tolist())
    cropped = image.crop((x1, y1, x2, y2))
    crop_tensor = clip_preprocess(cropped).unsqueeze(0).to(device)

    with torch.no_grad():
        image_feat = clip_model.encode_image(crop_tensor)
        image_feat /= image_feat.norm(dim=-1, keepdim=True)
        probs = (100.0 * image_feat @ text_features.T).softmax(dim=-1).squeeze()

    pred_label = text_prompts[probs.argmax()]
    confidence = probs.max().item()

    if confidence > 0.85 and pred_label != "nothing important":
        ax.add_patch(patches.Rectangle((x1, y1), x2 - x1, y2 - y1,
                     linewidth=2, edgecolor='red', facecolor='none'))
        ax.text(x1, y1 - 5, f"{pred_label} ({confidence:.2f})", color='yellow', fontsize=8)
        symbols_detected.append({
            "label": pred_label,
            "confidence": round(confidence, 2),
            "box": (x1, y1, x2, y2)
        })

plt.axis('off')
plt.title("Political symbols detected with YOLO + CLIP")
plt.tight_layout()
plt.show()

# === PRINT RESULTS ===
print("\nDetected symbols:")
if symbols_detected:
    for s in symbols_detected:
        print(f"- {s['label']} (conf: {s['confidence']}) at box {s['box']}")
else:
    print("No symbol detected.")
# Out:
# image 1/1 /home/vmeroni/data/images/525.png: 480x640 1 person, 43.1ms
# Speed: 2.1ms preprocess, 43.1ms inference, 132.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected symbols:
# - american (conf: 0.99) at box (312, 0, 1388, 1315)

# %%
import clip
import torch
from PIL import Image  # Make sure to import this

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Define text prompts
text = clip.tokenize(["american", "political logo", "flag", "nothing important"]).to(device)

# Load and preprocess the image
image = preprocess(Image.open("data/images/525.png")).unsqueeze(0).to(device)

# Encode image and text, compute similarity
with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)

    image_features /= image_features.norm(dim=-1, keepdim=True)
    text_features /= text_features.norm(dim=-1, keepdim=True)

    probs = (100.0 * image_features @ text_features.T).softmax(dim=-1)
    print("Probabilities:", probs)
# Out:
# Probabilities: tensor([[9.7656e-01, 7.4267e-05, 2.0584e-02, 2.7866e-03]], device='cuda:0', dtype=torch.float16)

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch

# Load the BLIP VQA model (not captioning)
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-vqa-base")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# Load and preprocess image
img = Image.open("/home/vmeroni/data/images/525.png").convert("RGB")

# Define your question
question = "Which country's flag is visible?"
inputs = processor(images=img, text=question, return_tensors="pt").to(device)
out = model.generate(**inputs)
answer = processor.decode(out[0], skip_special_tokens=True)

# Print results
print("Question:", question)
print("Answer:", answer)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747317761.432596 2562310 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747317761.437055 2562310 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747317761.448186 2562310 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747317761.448199 2562310 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747317761.448200 2562310 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747317761.448201 2562310 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Question: Which country's flag is visible?
# Answer: which country ' s flag is visible?

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch

# Load BLIP VQA model and processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-vqa-base")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# Load the image
img = Image.open("/home/vmeroni/data/images/525.png").convert("RGB")

# Define the question
question = "What flag is visible?"

# Prepare inputs and generate answer
inputs = processor(images=img, text=question, return_tensors="pt").to(device)
out = model.generate(**inputs)
answer = processor.decode(out[0], skip_special_tokens=True)

# Print question and answer
print("Question:", question)
print("Answer:", answer)
# Out:
# Question: What flag is visible?
# Answer: what flag is visible?

# %%
from ultralytics import YOLO
from PIL import Image
import torch
import clip
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# === SETUP ===
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-B/32", device=device)

# Define the text prompts for CLIP classification
text_prompts = ["american flag", "clown", "LGBTQ+","nothing important"]
text_tokens = clip.tokenize(text_prompts).to(device)
with torch.no_grad():
    text_features = clip_model.encode_text(text_tokens)
    text_features /= text_features.norm(dim=-1, keepdim=True)

# === LOAD IMAGE + YOLO DETECTION ===
image_path = "/home/vmeroni/data/images/1061.jpeg"
image = Image.open(image_path).convert("RGB")
yolo_model = YOLO("yolov8n.pt")
results = yolo_model(image_path)
r = results[0]

# === PROCESS DETECTIONS ===
fig, ax = plt.subplots(1)
ax.imshow(image)
symbols_detected = []

for box in r.boxes.xyxy:
    x1, y1, x2, y2 = map(int, box.tolist())
    cropped = image.crop((x1, y1, x2, y2))
    crop_tensor = clip_preprocess(cropped).unsqueeze(0).to(device)

    with torch.no_grad():
        image_feat = clip_model.encode_image(crop_tensor)
        image_feat /= image_feat.norm(dim=-1, keepdim=True)
        probs = (100.0 * image_feat @ text_features.T).softmax(dim=-1).squeeze()

    pred_label = text_prompts[probs.argmax()]
    confidence = probs.max().item()

    if confidence > 0.85 and pred_label != "nothing important":
        ax.add_patch(patches.Rectangle((x1, y1), x2 - x1, y2 - y1,
                     linewidth=2, edgecolor='red', facecolor='none'))
        ax.text(x1, y1 - 5, f"{pred_label} ({confidence:.2f})", color='yellow', fontsize=8)
        symbols_detected.append({
            "label": pred_label,
            "confidence": round(confidence, 2),
            "box": (x1, y1, x2, y2)
        })

plt.axis('off')
plt.title("Political symbols detected with YOLO + CLIP")
plt.tight_layout()
plt.show()

# === PRINT RESULTS ===
print("\nDetected symbols:")
if symbols_detected:
    for s in symbols_detected:
        print(f"- {s['label']} (conf: {s['confidence']}) at box {s['box']}")
else:
    print("No symbol detected.")
# Out:
# image 1/1 /home/vmeroni/data/images/1061.jpeg: 480x640 2 persons, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected symbols:
# - LGBTQ+ (conf: 0.93) at box (151, 53, 946, 766)

# %%
from ultralytics import YOLO
from PIL import Image
import torch
import clip
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# === SETUP ===
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-B/32", device=device)

# Define the text prompts for CLIP classification
text_prompts = ["communist flag", "nothing important"]
text_tokens = clip.tokenize(text_prompts).to(device)
with torch.no_grad():
    text_features = clip_model.encode_text(text_tokens)
    text_features /= text_features.norm(dim=-1, keepdim=True)

# === LOAD IMAGE + YOLO DETECTION ===
image_path = "/home/vmeroni/data/images/441.jpeg"
image = Image.open(image_path).convert("RGB")
yolo_model = YOLO("yolov8n.pt")
results = yolo_model(image_path)
r = results[0]

# === PROCESS DETECTIONS ===
fig, ax = plt.subplots(1)
ax.imshow(image)
symbols_detected = []

for box in r.boxes.xyxy:
    x1, y1, x2, y2 = map(int, box.tolist())
    cropped = image.crop((x1, y1, x2, y2))
    crop_tensor = clip_preprocess(cropped).unsqueeze(0).to(device)

    with torch.no_grad():
        image_feat = clip_model.encode_image(crop_tensor)
        image_feat /= image_feat.norm(dim=-1, keepdim=True)
        probs = (100.0 * image_feat @ text_features.T).softmax(dim=-1).squeeze()

    pred_label = text_prompts[probs.argmax()]
    confidence = probs.max().item()

    if confidence > 0.85 and pred_label != "nothing important":
        ax.add_patch(patches.Rectangle((x1, y1), x2 - x1, y2 - y1,
                     linewidth=2, edgecolor='red', facecolor='none'))
        ax.text(x1, y1 - 5, f"{pred_label} ({confidence:.2f})", color='yellow', fontsize=8)
        symbols_detected.append({
            "label": pred_label,
            "confidence": round(confidence, 2),
            "box": (x1, y1, x2, y2)
        })

plt.axis('off')
plt.title("Political symbols detected with YOLO + CLIP")
plt.tight_layout()
plt.show()

# === PRINT RESULTS ===
print("\nDetected symbols:")
if symbols_detected:
    for s in symbols_detected:
        print(f"- {s['label']} (conf: {s['confidence']}) at box {s['box']}")
else:
    print("No symbol detected.")
# Out:
# image 1/1 /home/vmeroni/data/images/441.jpeg: 480x640 7 persons, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected symbols:
# No symbol detected.

# %%
import os
import torch
import clip
from PIL import Image
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# === SETUP ===
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-L/14", device=device)
yolo_model = YOLO("yolov8n.pt")

# === LOAD REFERENCE SYMBOLS (from symbols/) ===
ref_folder = "data/simboli"
ref_paths = [os.path.join(ref_folder, f) for f in os.listdir(ref_folder)
             if f.lower().endswith((".jpg", ".png", ".jpeg"))]
ref_imgs = [clip_preprocess(Image.open(p).convert("RGB")).unsqueeze(0) for p in ref_paths]
ref_tensor = torch.cat(ref_imgs).to(device)

with torch.no_grad():
    ref_feats = clip_model.encode_image(ref_tensor)
    ref_feats /= ref_feats.norm(dim=-1, keepdim=True)

# === LOAD TARGET IMAGES (from images/) ===
target_folder = "data/images"
target_paths = [os.path.join(target_folder, f) for f in os.listdir(target_folder)
                if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# === PROCESS EACH TARGET IMAGE USING YOLO + CLIP (on crops) ===
results_summary = []

for path in target_paths:
    image = Image.open(path).convert("RGB")
    results = yolo_model(path)[0]

    sim_scores = []
    for box in results.boxes.xyxy:
        x1, y1, x2, y2 = map(int, box.tolist())
        pad = 10
        x1p = max(0, x1 - pad)
        y1p = max(0, y1 - pad)
        x2p = min(image.width, x2 + pad)
        y2p = min(image.height, y2 + pad)
        crop = image.crop((x1p, y1p, x2p, y2p))
        crop_tensor = clip_preprocess(crop).unsqueeze(0).to(device)

        with torch.no_grad():
            crop_feat = clip_model.encode_image(crop_tensor)
            crop_feat /= crop_feat.norm(dim=-1, keepdim=True)
            sims = (crop_feat @ ref_feats.T).squeeze().tolist()

        sim_scores.extend(sims)

    # Aggregate similarity: mean and max
    mean_sim = max_sim = 0.0
    if sim_scores:
        mean_sim = sum(sim_scores) / len(sim_scores)
        max_sim = max(sim_scores)

    results_summary.append({
        "image": os.path.basename(path),
        "mean_similarity": round(mean_sim, 4),
        "max_similarity": round(max_sim, 4),
        "num_regions": len(sim_scores)
    })

results_summary
# Out:
# image 1/1 /home/vmeroni/data/images/712.png: 480x640 1 person, 1 tie, 5.0ms
# Speed: 2.2ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/1031.jpeg: 640x640 8 persons, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/859.jpeg: 640x448 (no detections), 48.6ms
# Speed: 1.6ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/vmeroni/data/images/864.jpeg: 640x640 8 persons, 1 tie, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/595.jpeg: 640x384 4 persons, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/vmeroni/data/images/994.png: 640x480 6 persons, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/vmeroni/data/images/568.jpeg: 512x640 3 persons, 1 car, 1 dog, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/670.jpeg: 480x640 20 persons, 1 kite, 5.6ms
# Speed: 2.0ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/329.png: 640x640 2 persons, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/175.jpeg: 640x640 2 persons, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/616.jpeg: 640x448 1 person, 5.6ms
# Speed: 1.9ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/vmeroni/data/images/148.jpeg: 640x640 1 person, 1 tie, 1 chair, 1 bed, 5.3ms
# Speed: 2.3ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/985.jpeg: 480x640 1 person, 1 cup, 1 sandwich, 1 hot dog, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/326.png: 640x544 3 persons, 46.1ms
# Speed: 2.6ms preprocess, 46.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/vmeroni/data/images/1028.jpeg: 512x640 1 person, 2 bottles, 1 cup, 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/180.jpeg: 640x640 12 persons, 2 ties, 2 chairs, 1 book, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/759.jpeg: 640x640 16 persons, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/704.png: 640x640 8 persons, 5.2ms
# Speed: 2.6ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/153.jpeg: 640x640 1 person, 1 laptop, 5.0ms
# Speed: 2.3ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/323.png: 640x576 4 persons, 44.0ms
# Speed: 2.3ms preprocess, 44.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/vmeroni/data/images/545.png: 448x640 12 persons, 2 cell phones, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/vmeroni/data/images/963.jpeg: 480x640 1 person, 1 tie, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/764.jpeg: 640x480 2 persons, 1 bed, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/vmeroni/data/images/1023.jpeg: 480x640 4 persons, 1 tie, 1 sandwich, 1 pizza, 5.9ms
# Speed: 1.7ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/495.jpeg: 480x640 2 persons, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/701.png: 640x512 1 person, 1 tie, 1 couch, 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/vmeroni/data/images/737.jpeg: 480x640 2 persons, 1 tie, 1 frisbee, 3 kites, 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/538.jpeg: 608x640 4 persons, 42.4ms
# Speed: 1.9ms preprocess, 42.4ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/vmeroni/data/images/320.png: 640x544 2 persons, 1 tie, 1 bottle, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/vmeroni/data/images/383.png: 480x640 3 persons, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/380.png: 608x640 1 person, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/vmeroni/data/images/686.jpeg: 640x512 3 persons, 1 chair, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/vmeroni/data/images
 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/573.png: 512x640 2 persons, 1 tie, 6 cups, 1 chair, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/671.jpeg: 512x640 8 persons, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/951.png: 640x640 8 persons, 1 car, 1 tie, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/913.jpeg: 512x640 3 persons, 1 cell phone, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/644.jpeg: 640x416 6 persons, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/vmeroni/data/images/176.jpeg: 640x640 1 person, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/617.jpeg: 480x640 1 person, 2 bottles, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/570.png: 480x640 8 persons, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/149.jpeg: 640x640 7 persons, 1 tie, 2 chairs, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/986.jpeg: 480x640 3 persons, 7 bottles, 5 cups, 1 dining table, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/219.jpeg: 640x640 7 persons, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/1042.jpeg: 480x640 1 person, 1 cat, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/959.jpeg: 640x640 9 persons, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/1047.jpeg: 576x640 1 person, 13 chairs, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/vmeroni/data/images/450.jpeg: 512x640 3 persons, 3 ties, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/181.jpeg: 640x640 4 persons, 1 baseball bat, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/991.jpeg: 640x608 1 person, 1 tie, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/vmeroni/data/images/792.jpeg: 640x576 2 persons, 2 couchs, 1 bed, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/vmeroni/data/images/853_1.jpeg: 640x544 1 person, 1 chair, 2 potted plants, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/vmeroni/data/images/593.jpeg: 416x640 18 persons, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/vmeroni/data/images/949.png: 480x640 10 persons, 1 tie, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/765.jpeg: 480x640 1 person, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/738.jpeg: 480x640 2 persons, 1 tie, 1 chair, 1 potted plant, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/853_2.jpeg: 608x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/vmeroni/data/images/808.jpeg: 480x640 7 persons, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/539.jpeg: 512x640 4 persons, 1 tie, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/1039.jpeg: 480x640 6 persons, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/770.jpeg: 480x640 9 persons, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/840.jpeg: 480x640 1 person, 1 boat, 2 birds, 1 tie, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/565.png: 640x448 1 person, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/vmeroni/data/images/544.jpeg: 480x640 13 persons, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/184.png: 576x640 5 persons, 2 parking meters, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/vmeroni/data/images/721.png: 448x640 1 person, 1 airplane, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/vmeroni/data/images/943.png: 544x640 2 persons, 1 tie, 1 frisbee, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/vmeroni/data/images/1057.png: 512x640 7 persons, 1 cup, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/vmeroni/data/images/886.jpeg: 448x640 1 person, 1 tie, 1 baseball bat, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/vmeroni/data/images/687.jpeg: 640x640 1 person, 1 tie, 1 clock, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/1005.jpeg: 480x640 1 person, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/929.jpeg: 480x640 7 persons, 1 umbrella, 2 kites, 1 cell phone, 5.9ms
# Speed: 1.9ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/151.jpeg: 640x640 6 persons, 3 ties, 6.3ms
# Speed: 2.5ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/1025.jpeg: 480x640 1 person, 1 cat, 1 keyboard, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/124.jpeg: 640x640 9 persons, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/493.jpeg: 480x640 6 persons, 1 chair, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/934.jpeg: 640x640 7 persons, 2 boats, 1 tie, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/665.jpeg: 480x640 2 persons, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/907.jpeg: 640x640 1 person, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/708.jpeg: 480x640 1 person, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/439.jpeg: 384x640 3 persons, 1 tie, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/vmeroni/data/images/1018.jpeg: 640x640 1 person, 1 tie, 1 scissors, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/716.png: 640x480 2 persons, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/vmeroni/data/images/912.jpeg: 480x640 2 persons, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/663.png: 544x640 1 person, 1 tie, 7 kites, 6.1ms
# ...
#   'max_similarity': 0.6675,
#   'num_regions': 60},
#  {'image': '709.jpeg',
#   'mean_similarity': 0.6444,
#   'max_similarity': 0.7173,
#   'num_regions': 55},
#  {'image': '467.png',
#   'mean_similarity': 0.5719,
#   'max_similarity': 0.6406,
#   'num_regions': 45},
#  {'image': '542.jpeg',
#   'mean_similarity': 0.5114,
#   'max_similarity': 0.6357,
#   'num_regions': 25},
#  {'image': '884.jpeg',
#   'mean_similarity': 0.6097,
#   'max_similarity': 0.6958,
#   'num_regions': 30},
#  {'image': '1051.png',
#   'mean_similarity': 0.5729,
#   'max_similarity': 0.6245,
#   'num_regions': 15},
#  {'image': '857.jpeg',
#   'mean_similarity': 0.5838,
#   'max_similarity': 0.6782,
#   'num_regions': 45},
#  {'image': '588.jpeg',
#   'mean_similarity': 0.5635,
#   'max_similarity': 0.6177,
#   'num_regions': 20},
#  {'image': '514.png',
#   'mean_similarity': 0.5909,
#   'max_similarity': 0.6899,
#   'num_regions': 45},
#  {'image': '355.png',
#   'mean_similarity': 0.5494,
#   'max_similarity': 0.7148,
#   'num_regions': 90},
#  {'image': '862.jpeg',
#   'mean_similarity': 0.4982,
#   'max_similarity': 0.5688,
#   'num_regions': 15},
#  {'image': '1021.jpeg',
#   'mean_similarity': 0.5774,
#   'max_similarity': 0.6572,
#   'num_regions': 30},
#  {'image': '835.jpeg',
#   'mean_similarity': 0.5249,
#   'max_similarity': 0.6562,
#   'num_regions': 15},
#  {'image': '890_3.jpeg',
#   'mean_similarity': 0.5685,
#   'max_similarity': 0.5962,
#   'num_regions': 5},
#  {'image': '352.png',
#   'mean_similarity': 0.5424,
#   'max_similarity': 0.6953,
#   'num_regions': 45},
#  {'image': '1024.jpeg',
#   'mean_similarity': 0.595,
#   'max_similarity': 0.6494,
#   'num_regions': 40},
#  {'image': '890_2.jpeg',
#   'mean_similarity': 0.5404,
#   'max_similarity': 0.5874,
#   'num_regions': 30},
#  {'image': '978.jpeg',
#   'mean_similarity': 0.5613,
#   'max_similarity': 0.6421,
#   'num_regions': 40},
#  {'image': '787.png',
#   'mean_similarity': 0.577,
#   'max_similarity': 0.689,
#   'num_regions': 15},
#  {'image': '910.jpeg',
#   'mean_similarity': 0.6143,
#   'max_similarity': 0.6851,
#   'num_regions': 35},
#  {'image': '844_1.jpeg',
#   'mean_similarity': 0.6029,
#   'max_similarity': 0.7041,
#   'num_regions': 65},
#  {'image': '173.jpeg',
#   'mean_similarity': 0.5974,
#   'max_similarity': 0.6836,
#   'num_regions': 30},
#  {'image': '146.jpeg',
#   'mean_similarity': 0.5745,
#   'max_similarity': 0.6943,
#   'num_regions': 20},
#  {'image': '983.jpeg',
#   'mean_similarity': 0.6086,
#   'max_similarity': 0.6895,
#   'num_regions': 30},
#  {'image': '784.png',
#   'mean_similarity': 0.5874,
#   'max_similarity': 0.6455,
#   'num_regions': 15},
#  {'image': '757.jpeg',
#   'mean_similarity': 0.566,
#   'max_similarity': 0.6235,
#   'num_regions': 70},
#  {'image': '781.png',
#   'mean_similarity': 0.4422,
#   'max_similarity': 0.5649,
#   'num_regions': 80},
#  {'image': '762.jpeg',
#   'mean_similarity': 0.5959,
#   'max_similarity': 0.6763,
#   'num_regions': 15},
#  {'image': '735.jpeg',
#   'mean_similarity': 0.6394,
#   'max_similarity': 0.7129,
#   'num_regions': 10},
#  {'image': '831.png',
#   'mean_similarity': 0.6081,
#   'max_similarity': 0.6499,
#   'num_regions': 10},
#  {'image': '805.jpeg',
#   'mean_similarity': 0.5936,
#   'max_similarity': 0.6685,
#   'num_regions': 120},
#  {'image': '536.jpeg',
#   'mean_similarity': 0.5396,
#   'max_similarity': 0.6626,
#   'num_regions': 25},
#  {'image': '267.jpeg',
#   'mean_similarity': 0.5571,
#   'max_similarity': 0.7065,
#   'num_regions': 125},
#  {'image': '509.jpeg',
#   'mean_similarity': 0.5862,
#   'max_similarity': 0.646,
#   'num_regions': 30},
#  {'image': '878.jpeg',
#   'mean_similarity': 0.537,
#   'max_similarity': 0.5825,
#   'num_regions': 15},
#  {'image': '168_2.jpeg',
#   'mean_similarity': 0.4856,
#   'max_similarity': 0.6523,
#   'num_regions': 35},
#  {'image': '810.jpeg',
#   'mean_similarity': 0.4063,
#   'max_similarity': 0.4485,
#   'num_regions': 20},
#  {'image': '679.jpeg',
#   'mean_similarity': 0.6063,
#   'max_similarity': 0.688,
#   'num_regions': 10},
#  {'image': '541.jpeg',
#   'mean_similarity': 0.5691,
#   'max_similarity': 0.7095,
#   'num_regions': 40},
#  {'image': '779.png',
#   'mean_similarity': 0.5513,
#   'max_similarity': 0.6094,
#   'num_regions': 35},
#  {'image': '853_3.jpeg',
#   'mean_similarity': 0.5341,
#   'max_similarity': 0.6895,
#   'num_regions': 10},
#  {'image': '1061.jpeg',
#   'mean_similarity': 0.6085,
#   'max_similarity': 0.6191,
#   'num_regions': 10},
#  {'image': '883.jpeg',
#   'mean_similarity': 0.5505,
#   'max_similarity': 0.6523,
#   'num_regions': 65},
#  {'image': '684.jpeg',
#   'mean_similarity': 0.6272,
#   'max_similarity': 0.7002,
#   'num_regions': 20},
#  {'image': '1050.png',
#   'mean_similarity': 0.5414,
#   'max_similarity': 0.6768,
#   'num_regions': 15},
#  {'image': '926.jpeg',
#   'mean_similarity': 0.4291,
#   'max_similarity': 0.4443,
#   'num_regions': 5},
#  {'image': '458.jpeg',
#   'mean_similarity': 0.6142,
#   'max_similarity': 0.7026,
#   'num_regions': 10},
#  {'image': '121.jpeg',
#   'mean_similarity': 0.5669,
#   'max_similarity': 0.6484,
#   'num_regions': 70},
#  {'image': '999.jpeg',
#   'mean_similarity': 0.5292,
#   'max_similarity': 0.6011,
#   'num_regions': 15},
#  {'image': '490.jpeg',
#   'mean_similarity': 0.6157,
#   'max_similarity': 0.668,
#   'num_regions': 15},
#  {'image': '931.jpeg',
#   'mean_similarity': 0.5737,
#   'max_similarity': 0.6069,
#   'num_regions': 5},
#  {'image': '904.jpeg',
#   'mean_similarity': 0.4311,
#   'max_similarity': 0.4497,
#   'num_regions': 10},
#  {'image': '823.png',
#   'mean_similarity': 0.6081,
#   'max_similarity': 0.6499,
#   'num_regions': 10},
#  {'image': '237.jpeg',
#   'mean_similarity': 0.5052,
#   'max_similarity': 0.5615,
#   'num_regions': 15},
#  {'image': '710.jpeg',
#   'mean_similarity': 0.5742,
#   'max_similarity': 0.6675,
#   'num_regions': 75},
#  {'image': '441.jpeg',
#   'mean_similarity': 0.5382,
#   'max_similarity': 0.6348,
#   'num_regions': 35},
#  {'image': '661.png',
#   'mean_similarity': 0.5705,
#   'max_similarity': 0.6787,
#   'num_regions': 20},
#  {'image': '215.jpeg',
#   'mean_similarity': 0.5122,
#   'max_similarity': 0.5991,
#   'num_regions': 10},
#  {'image': '1016.jpeg',
#   'mean_similarity': 0.4652,
#   'max_similarity': 0.489,
#   'num_regions': 5},
#  {'image': '705.png',
#   'mean_similarity': 0.5824,
#   'max_similarity': 0.6099,
#   'num_regions': 5},
#  {'image': '826.jpeg',
#   'mean_similarity': 0.5701,
#   'max_similarity': 0.6416,
#   'num_regions': 30},
#  {'image': '220.jpeg',
#   'mean_similarity': 0.5966,
#   'max_similarity': 0.6606,
#   'num_regions': 50},
#  {'image': '702.png',
#   'mean_similarity': 0.5628,
#   'max_similarity': 0.5938,
#   'num_regions': 5},
#  {'image': '924.png',
#   'mean_similarity': 0.6081,
#   'max_similarity': 0.6499,
#   'num_regions': 10},
#  {'image': '899.jpeg',
#   'mean_similarity': 0.5379,
#   'max_similarity': 0.6133,
#   'num_regions': 40},
#  {'image': '804.jpeg',
#   'mean_similarity': 0.589,
#   'max_similarity': 0.6914,
#   'num_regions': 35},
#  {'image': '164.jpeg',
#   'mean_similarity': 0.5059,
#   'max_similarity': 0.5464,
#   'num_regions': 5},
#  {'image': '137.jpeg',
#   'mean_similarity': 0.5606,
#   'max_similarity': 0.6675,
#   'num_regions': 60},
#  {'image': '974.jpeg',
#   'mean_similarity': 0.4788,
#   'max_similarity': 0.5449,
#   'num_regions': 20},
#  {'image': '1038.jpeg',
#   'mean_similarity': 0.5352,
#   'max_similarity': 0.5669,
#   'num_regions': 25},
#  {'image': '317_2.jpeg',
#   'mean_similarity': 0.565,
#   'max_similarity': 0.6416,
#   'num_regions': 25},
#  {'image': '678.jpeg',
#   'mean_similarity': 0.5905,
#   'max_similarity': 0.6699,
#   'num_regions': 80},
#  {'image': '610.jpeg',
#   'mean_similarity': 0.5896,
#   'max_similarity': 0.6641,
#   'num_regions': 80},
#  {'image': '381.png',
#   'mean_similarity': 0.5056,
#   'max_similarity': 0.5459,
#   'num_regions': 5},
#  {'image': '142.jpeg',
#   'mean_similarity': 0.5974,
#   'max_similarity': 0.7192,
#   'num_regions': 70},
#  {'image': '683.jpeg',
#   'mean_similarity': 0.608,
#   'max_similarity': 0.7119,
#   'num_regions': 60},
#  {'image': '753.jpeg',
#   'mean_similarity': 0.5081,
#   'max_similarity': 0.6196,
#   'num_regions': 15},
#  {'image': '484.jpeg',
#   'mean_similarity': 0.5674,
#   'max_similarity': 0.6157,
#   'num_regions': 20},
#  {'image': '925.jpeg',
#   'mean_similarity': 0.5279,
#   'max_similarity': 0.6431,
#   'num_regions': 20},
#  {'image': '726.jpeg',
#   'mean_similarity': 0.5293,
#   'max_similarity': 0.6504,
#   'num_regions': 15},
#  {'image': '457.jpeg',
#   'mean_similarity': 0.4597,
#   'max_similarity': 0.48,
#   'num_regions': 5},
#  {'image': '930.jpeg',
#   'mean_similarity': 0.5552,
#   'max_similarity': 0.6016,
#   'num_regions': 10},
#  {'image': '799.jpeg',
#   'mean_similarity': 0.5783,
#   'max_similarity': 0.7031,
#   'num_regions': 25},
#  {'image': '379.png',
#   'mean_similarity': 0.5593,
#   'max_similarity': 0.6187,
#   'num_regions': 35},
#  {'image': '505.jpeg',
#   'mean_similarity': 0.5902,
#   'max_similarity': 0.6714,
#   'num_regions': 25},
#  {'image': '376.png',
#   'mean_similarity': 0.6058,
#   'max_similarity': 0.6528,
#   'num_regions': 15},
#  {'image': '874.jpeg',
#   'mean_similarity': 0.5224,
#   'max_similarity': 0.5859,
#   'num_regions': 10},
#  {'image': '847.jpeg',
#   'mean_similarity': 0.4726,
#   'max_similarity': 0.6284,
#   'num_regions': 10},
#  {'image': '510.jpeg',
#   'mean_similarity': 0.5343,
#   'max_similarity': 0.5786,
#   'num_regions': 10},
#  {'image': '852.jpeg',
#   'mean_similarity': 0.4969,
#   'max_similarity': 0.6143,
#   'num_regions': 15},
#  {'image': '1026.jpeg',
#   'mean_similarity': 0.5439,
#   'max_similarity': 0.5664,
#   'num_regions': 5},
#  {'image': '639.png',
#   'mean_similarity': 0.5402,
#   'max_similarity': 0.6133,
#   'num_regions': 15},
#  {'image': '626.jpeg',
#   'mean_similarity': 0.6287,
#   'max_similarity': 0.7285,
#   'num_regions': 15},
#  {'image': '158.jpeg',
#   'mean_similarity': 0.5431,
#   'max_similarity': 0.6694,
#   'num_regions': 100},
#  {'image': '995.jpeg',
#   'mean_similarity': 0.5867,
#   'max_similarity': 0.6904,
#   'num_regions': 70},
#  {'image': '636.png',
#   'mean_similarity': 0.4836,
#   'max_similarity': 0.562,
#   'num_regions': 25},
#  {'image': '317_1.jpeg',
#   'mean_similarity': 0.5505,
#   'max_similarity': 0.6523,
#   'num_regions': 65},
#  {'image': '308.png',
#   'mean_similarity': 0.5533,
#   'max_similarity': 0.6504,
#   'num_regions': 20},
#  {'image': '900.jpeg',
#   'mean_similarity': 0.5545,
#   'max_similarity': 0.6162,
#   'num_regions': 15},
#  {'image': '769.jpeg',
#   'mean_similarity': 0.5702,
#   'max_similarity': 0.6011,
#   'num_regions': 5},
#  {'image': '477.png',
#   'mean_similarity': 0.532,
#   'max_similarity': 0.6489,
#   'num_regions': 15},
#  {'image': '699.png',
#   'mean_similarity': 0.5524,
#   'max_similarity': 0.6743,
#   'num_regions': 15},
#  {'image': '163.jpeg',
#   'mean_similarity': 0.4644,
#   'max_similarity': 0.5098,
#   'num_regions': 5},
#  {'image': '604.jpeg',
#   'mean_similarity': 0.5585,
#   'max_similarity': 0.6455,
#   'num_regions': 20},
#  {'image': '633.png',
#   'mean_similarity': 0.6163,
#   'max_similarity': 0.7134,
#   'num_regions': 65},
#  {'image': '136.jpeg',
#   'mean_similarity': 0.5648,
#   'max_similarity': 0.6362,
#   'num_regions': 25},
#  {'image': '973.jpeg',
#   'mean_similarity': 0.5644,
#   'max_similarity': 0.6689,
#   'num_regions': 75},
#  {'image': '527.png',
#   'mean_similarity': 0.5981,
#   'max_similarity': 0.6777,
#   'num_regions': 35},
#  {'image': '474.png',
#   'mean_similarity': 0.5791,
#   'max_similarity': 0.7764,
#   'num_regions': 30},
#  {'image': '946.jpeg',
#   'mean_similarity': 0.4435,
#   'max_similarity': 0.4775,
#   'num_regions': 5},
#  {'image': '548.jpeg',
#   'mean_similarity': 0.549,
#   'max_similarity': 0.6001,
#   'num_regions': 40},
#  {'image': '524.png',
#   'mean_similarity': 0.4602,
#   'max_similarity': 0.5962,
#   'num_regions': 10},
#  {'image': '471.png',
#   'mean_similarity': 0.6438,
#   'max_similarity': 0.6929,
#   'num_regions': 10},
#  {'image': '752.jpeg',
#   'mean_similarity': 0.5244,
#   'max_similarity': 0.6191,
#   'num_regions': 15},
#  {'image': '553.jpeg',
#   'mean_similarity': 0.5852,
#   'max_similarity': 0.7031,
#   'num_regions': 45},
#  {'image': '521.png',
#   'mean_similarity': 0.4987,
#   'max_similarity': 0.6001,
#   'num_regions': 105},
#  {'image': '895.jpeg',
#   'mean_similarity': 0.6291,
#   'max_similarity': 0.6846,
#   'num_regions': 20},
#  {'image': '800.jpeg',
#   'mean_similarity': 0.5683,
#   'max_similarity': 0.6616,
#   'num_regions': 20},
#  {'image': '797.png',
#   'mean_similarity': 0.5789,
#   'max_similarity': 0.647,
#   'num_regions': 70},
#  {'image': '669.jpeg',
#   'mean_similarity': 0.5545,
#   'max_similarity': 0.6162,
#   'num_regions': 15},
#  {'image': '531.jpeg',
#   'mean_similarity': 0.5167,
#   'max_similarity': 0.6641,
#   'num_regions': 15},
#  {'image': '1022.jpeg',
#   'mean_similarity': 0.5992,
#   'max_similarity': 0.6226,
#   'num_regions': 5},
#  {'image': '469.png',
#   'mean_similarity': 0.5255,
#   'max_similarity': 0.6885,
#   'num_regions': 15},
#  {'image': '953.png',
#   'mean_similarity': 0.567,
#   'max_similarity': 0.6655,
#   'num_regions': 15},
#  {'image': '873.jpeg',
#   'mean_similarity': 0.5937,
#   'max_similarity': 0.6841,
#   'num_regions': 50},
#  {'image': '674.jpeg',
#   'mean_similarity': 0.6036,
#   'max_similarity': 0.6411,
#   'num_regions': 10},
#  {'image': '916.jpeg',
#   'mean_similarity': 0.4788,
#   'max_similarity': 0.5449,
#   'num_regions': 20},
#  {'image': '466.png',
#   'mean_similarity': 0.6069,
#   'max_similarity': 0.7422,
#   'num_regions': 60},
#  {'image': '647.jpeg',
#   'mean_similarity': 0.582,
#   'max_similarity': 0.6919,
#   'num_regions': 55},
#  {'image': '448.jpeg',
#   'mean_similarity': 0.5599,
#   'max_similarity': 0.6514,
#   'num_regions': 55},
#  {'image': '179.jpeg',
#   'mean_similarity': 0.5397,
#   'max_similarity': 0.6128,
#   'num_regions': 15},
#  {'image': '453.jpeg',
#   'mean_similarity': 0.5727,
#   'max_similarity': 0.7827,
#   'num_regions': 25},
#  {'image': '795.jpeg',
#   'mean_similarity': 0.4217,
#   'max_similarity': 0.4363,
#   'num_regions': 5},
#  {'image': '596.jpeg',
#   'mean_similarity': 0.58,
#   'max_similarity': 0.686,
#   'num_regions': 55},
#  {'image': '768.jpeg',
#   'mean_similarity': 0.588,
#   'max_similarity': 0.6753,
#   'num_regions': 30},
#  {'image': '948.png',
#   'mean_similarity': 0.6114,
#   'max_similarity': 0.6416,
#   'num_regions': 15},
#  {'image': '773.jpeg',
#   'mean_similarity': 0.402,
#   'max_similarity': 0.4253,
#   'num_regions': 5},
#  {'image': '843.jpeg',
#   'mean_similarity': 0.5764,
#   'max_similarity': 0.6577,
#   'num_regions': 55},
#  {'image': '564.png',
#   'mean_similarity': 0.5147,
#   'max_similarity': 0.6226,
#   'num_regions': 20},
#  {'image': '786.png',
#   'mean_similarity': 0.6098,
#   'max_similarity': 0.7148,
#   'num_regions': 55},
#  {'image': '547.jpeg',
#   'mean_similarity': 0.53,
#   'max_similarity': 0.5605,
#   'num_regions': 5},
#  {'image': '1035.jpeg',
#   'mean_similarity': 0.5574,
#   'max_similarity': 0.6821,
#   'num_regions': 20},
#  {'image': '942.png',
#   'mean_similarity': 0.5021,
#   'max_similarity': 0.623,
#   'num_regions': 15},
#  {'image': '783.png',
#   'mean_similarity': 0.4645,
#   'max_similarity': 0.6221,
#   'num_regions': 10},
#  {'image': '552.jpeg',
#   'mean_similarity': 0.533,
#   'max_similarity': 0.6172,
#   'num_regions': 20},
#  {'image': '622.jpeg',
#   'mean_similarity': 0.5917,
#   'max_similarity': 0.6738,
#   'num_regions': 20},
#  {'image': '154.jpeg',
#   'mean_similarity': 0.5528,
#   'max_similarity': 0.5752,
#   'num_regions': 5},
#  {'image': '127.jpeg',
#   'mean_similarity': 0.5632,
#   'max_similarity': 0.6748,
#   'num_regions': 20},
#  {'image': '964.jpeg',
#   'mean_similarity': 0.4867,
#   'max_similarity': 0.5103,
#   'num_regions': 15},
#  {'image': '496.jpeg',
#   'mean_similarity': 0.6106,
#   'max_similarity': 0.6421,
#   'num_regions': 15},
#  {'image': '600.jpeg',
#   'mean_similarity': 0.365,
#   'max_similarity': 0.3782,
#   'num_regions': 5},
#  {'image': '718.png',
#   'mean_similarity': 0.5289,
#   'max_similarity': 0.6348,
#   'num_regions': 70},
#  {'image': '132.jpeg',
#   'mean_similarity': 0.5884,
#   'max_similarity': 0.6714,
#   'num_regions': 20},
#  {'image': '337.png',
#   'mean_similarity': 0.4768,
#   'max_similarity': 0.6055,
#   'num_regions': 15},
#  {'image': '915.jpeg',
#   'mean_similarity': 0.5024,
#   'max_similarity': 0.6118,
#   'num_regions': 20},
#  {'image': '715.png',
#   'mean_similarity': 0.5233,
#   'max_similarity': 0.6846,
#   'num_regions': 20},
#  {'image': '447.jpeg',
#   'mean_similarity': 0.5827,
#   'max_similarity': 0.7056,
#   'num_regions': 70},
#  {'image': '778.png',
#   'mean_similarity': 0.6104,
#   'max_similarity': 0.6602,
#   'num_regions': 10}]

# %%
import os
from ultralytics import YOLO
from PIL import Image
import torch
import clip
from tqdm import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-L/14", device=device)
yolo_model = YOLO("yolov8n.pt")

# %%
text_prompts = [
    "army",
    "prisoner",
    "american flag",
    "communist symbol",
    "police",
    "rainbow pride flag", 
    "nothing important"
]

text_tokens = clip.tokenize(text_prompts).to(device)
with torch.no_grad():
    text_features = clip_model.encode_text(text_tokens)
    text_features /= text_features.norm(dim=-1, keepdim=True)

# %%
image_dir = "/home/vmeroni/data/images"  
image_paths = [os.path.join(image_dir, f) for f in os.listdir(image_dir)
               if f.lower().endswith((".jpg", ".jpeg", ".png"))]

detailed_detected_data = []

for image_path in tqdm(image_paths):
    image = Image.open(image_path).convert("RGB")
    results = yolo_model(image_path)[0]

    symbol_scores = {}

    if results.boxes is not None and results.boxes.xyxy.numel() > 0:
        for box in results.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box.tolist())
            cropped = image.crop((x1, y1, x2, y2))
            crop_tensor = clip_preprocess(cropped).unsqueeze(0).to(device)

            with torch.no_grad():
                image_feat = clip_model.encode_image(crop_tensor)
                image_feat /= image_feat.norm(dim=-1, keepdim=True)
                probs = (100.0 * image_feat @ text_features.T).softmax(dim=-1).squeeze()

            for idx, label in enumerate(text_prompts):
                score = probs[idx].item()
                if score > 0.9 and label != "nothing important":
                    if label in symbol_scores:
                        symbol_scores[label] = max(symbol_scores[label], score)
                    else:
                        symbol_scores[label] = score

    if symbol_scores:
        detailed_detected_data.append({
            "image": os.path.basename(image_path),
            "detected_symbols": {k: round(v, 4) for k, v in symbol_scores.items()}
        })
# Out:
#   0%|                                                                                                                | 0/624 [00:00<?, ?it/s]
# image 1/1 /home/vmeroni/data/images/712.png: 480x640 1 person, 1 tie, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#   0%|▏                                                                                                       | 1/624 [00:00<01:16,  8.16it/s]
# image 1/1 /home/vmeroni/data/images/1031.jpeg: 640x640 8 persons, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   0%|▎                                                                                                       | 2/624 [00:00<02:01,  5.12it/s]
# image 1/1 /home/vmeroni/data/images/859.jpeg: 640x448 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/vmeroni/data/images/864.jpeg: 640x640 8 persons, 1 tie, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   1%|▋                                                                                                       | 4/624 [00:00<01:34,  6.54it/s]
# image 1/1 /home/vmeroni/data/images/595.jpeg: 640x384 4 persons, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   1%|▊                                                                                                       | 5/624 [00:00<01:34,  6.53it/s]
# image 1/1 /home/vmeroni/data/images/994.png: 640x480 6 persons, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#   1%|█                                                                                                       | 6/624 [00:00<01:40,  6.13it/s]
# image 1/1 /home/vmeroni/data/images/568.jpeg: 512x640 3 persons, 1 car, 1 dog, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#   1%|█▏                                                                                                      | 7/624 [00:01<01:35,  6.49it/s]
# image 1/1 /home/vmeroni/data/images/670.jpeg: 480x640 20 persons, 1 kite, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#   1%|█▎                                                                                                      | 8/624 [00:01<02:51,  3.59it/s]
# image 1/1 /home/vmeroni/data/images/329.png: 640x640 2 persons, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   1%|█▌                                                                                                      | 9/624 [00:01<02:23,  4.28it/s]
# image 1/1 /home/vmeroni/data/images/175.jpeg: 640x640 2 persons, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/vmeroni/data/images/616.jpeg: 640x448 1 person, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#   2%|█▊                                                                                                     | 11/624 [00:01<01:33,  6.54it/s]
# image 1/1 /home/vmeroni/data/images/148.jpeg: 640x640 1 person, 1 tie, 1 chair, 1 bed, 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   2%|█▉                                                                                                     | 12/624 [00:02<01:29,  6.83it/s]
# image 1/1 /home/vmeroni/data/images/985.jpeg: 480x640 1 person, 1 cup, 1 sandwich, 1 hot dog, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌| 621/624 [01:50<00:00,  6.98it/s]
# image 1/1 /home/vmeroni/data/images/715.png: 512x640 1 person, 1 chair, 2 teddy bears, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████▋| 622/624 [01:50<00:00,  6.72it/s]
# image 1/1 /home/vmeroni/data/images/447.jpeg: 512x640 9 persons, 1 bench, 4 chairs, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████▊| 623/624 [01:50<00:00,  4.86it/s]
# image 1/1 /home/vmeroni/data/images/778.png: 640x512 1 clock, 1 scissors, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 624/624 [01:50<00:00,  5.64it/s]

# %%
df = pd.DataFrame(detailed_detected_data)
df.to_csv("detailed_detected_data.csv", index=False)
print(df.head()z
# Out:
#       image              detected_symbols
# 0   994.png            {'police': 0.9619}
# 1  670.jpeg  {'communist symbol': 0.9565}
# 2  148.jpeg          {'prisoner': 0.9951}
# 3  180.jpeg          {'prisoner': 0.9971}
# 4  153.jpeg          {'prisoner': 0.9956}

# %%
import pandas as pd
import ast
import os

# Load existing CSV
df = pd.read_csv("detected_symbols_over_090.csv")
df['detected_symbols'] = df['detected_symbols'].apply(ast.literal_eval)

# Get already processed image names
existing_images = set(df['image'])

# Get all image paths in the folder
image_folder = "data/images"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder)
               if f.lower().endswith((".jpg", ".jpeg", ".png"))]

# Filter only new images (not in existing CSV)
new_image_paths = [p for p in image_paths if os.path.basename(p) not in existing_images]

# %%
import torch
import clip
from PIL import Image
from ultralytics import YOLO

# Load models
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-L/14", device=device)
yolo_model = YOLO("yolov8n.pt")

# Load reference images for communist symbols
symbol_folder = "data/simboli"
ref_paths = [os.path.join(symbol_folder, f) for f in os.listdir(symbol_folder)
             if f.lower().endswith((".jpg", ".png", ".jpeg"))]
ref_images = [clip_preprocess(Image.open(p).convert("RGB")).unsqueeze(0) for p in ref_paths]
ref_tensor = torch.cat(ref_images).to(device)

with torch.no_grad():
    ref_features = clip_model.encode_image(ref_tensor)
    ref_features /= ref_features.norm(dim=-1, keepdim=True)

# Analyze new images
new_detected = []

for path in new_image_paths:
    image = Image.open(path).convert("RGB")
    results = yolo_model(path)[0]

    sim_scores = []
    for box in results.boxes.xyxy:
        x1, y1, x2, y2 = map(int, box.tolist())
        pad = 10
        x1p = max(0, x1 - pad)
        y1p = max(0, y1 - pad)
        x2p = min(image.width, x2 + pad)
        y2p = min(image.height, y2 + pad)
        crop = image.crop((x1p, y1p, x2p, y2p))
        crop_tensor = clip_preprocess(crop).unsqueeze(0).to(device)

        with torch.no_grad():
            crop_feat = clip_model.encode_image(crop_tensor)
            crop_feat /= crop_feat.norm(dim=-1, keepdim=True)
            sims = (crop_feat @ ref_features.T).squeeze().tolist()

        sim_scores.extend(sims)
     
    
    if sim_scores:
       max_sim = max(sim_scores)
       if max_sim > 0.738:
          new_detected.append({
            "image": os.path.basename(path),
            "detected_symbols": ["communist symbol"]
            })

# Append to original dataframe and save
updated_df = pd.concat([df, pd.DataFrame(new_detected)], ignore_index=True)
updated_df.to_csv("symbols_detected_over_090_detailed.csv", index=False)
print(f"✅ Added {len(new_detected)} new images with 'communist symbol'")
# Out:
# image 1/1 /home/vmeroni/data/images/712.png: 480x640 1 person, 1 tie, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/vmeroni/data/images/
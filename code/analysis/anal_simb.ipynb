# %% [markdown]
# # Symbol Analysis in Communication Dataset
#
# This notebook performs a detailed analysis of symbolic elements detected in a communication-related dataset.
#
# ## Objectives
#
# - Merge main metadata with symbol detection results.
# - Analyze frequency and distribution of detected visual symbols.
# - Explore relationships between symbols and other features such as:
#   - Villains
#   - Domains
#   - Heroes
#   - Years
#   - Communication goals
#
# ## Workflow Summary
#
# 1. **Data Loading**:
#    - Load the main dataset (`data-2324-no-ver.csv`).
#    - Load the symbol detection results (`symbols_detected_over_090_detailed.csv`).
#
# 2. **Preprocessing**:
#    - Extract `incident_id` from image filenames.
#    - Merge symbol data with the main metadata using `incident_id`.
#
# 3. **Symbol Analysis**:
#    - Parse and explode the list of detected symbols.
#    - Count symbol occurrences.
#    - Group and cross-tabulate symbols against other categorical fields.
#
# 4. **Visualization**:
#    - Generate bar plots showing symbol frequencies.
#    - Display detailed contingency tables for symbol interactions with other variables.
#
# 5. **Filtering**:
#    - Focus the analysis on the top 10 most frequent categories per variable for clearer plots.
#
# ## Tools Used
#
# - **Pandas** for data manipulation.
# - **Matplotlib** for visualizations.
# - **AST** for parsing stringified lists.
#
# ## Applications
#
# This analysis helps understand how symbolic representations are used across different narrative elements in the dataset and can support further tasks such as content classification or semiotics research.

# %%
import pandas as pd
df=pd.read_csv('data/data-2324-no-ver.csv')
df.head()
# Out:
#    Unnamed: 0  incident_id report_id  date_coded  \
# 0           0          203        17  2024-02-12
# 1           1          186        18  2024-02-04
# 2           2          187        19  2024-02-05
# 3           3          188        20  2024-02-05
# 4           4          201        25  2024-02-09
#
#                                                  url  \
# 0  https://twitter.com/DouglasLucas/status/171631...
# 1  https://twitter.com/21WIRE/status/165300993699...
# 2      https://www.facebook.com/reel/894486844951526
# 3  https://twitter.com/JebraFaushay/status/165937...
# 4  https://twitter.com/JackPosobiec/status/163383...
#
#                                                 file screenshot date_posted  \
# 0  Screenshot 2024-02-12 at 12.47.24 PM.png (http...        NaN  2023-10-23
# 1  "Patrick Henningsen on X_ _⭕️ Granted, this mu...        NaN  2023-05-01
# 2  deepfake 19.html (https://v5.airtableuserconte...        NaN  2023-05-03
# 3  Deepfake 20.html (https://v5.airtableuserconte...        NaN  2023-05-18
# 4  Screenshot 2024-02-09 134519.png (https://v5.a...        NaN  2023-03-09
#
#   format                                         transcript  ...  \
# 0  image                                                NaN  ...
# 1  video  "Today is today, and yesterday was today yeste...  ...
# 2  video  “Today is today, and yesterday is today yester...  ...
# 3  video  "Excuse me, excuse me. I need everyone in the ...  ...
# 4  video  I'll tell you something the deepfake that Jack...  ...
#
#                                 text_around_deepfake           harm_evidence  \
# 0  AI and the end of photographic truth? Deceptiv...  political_interference
# 1  ⭕️ Granted, this must be a deep fake, but rega...        non_identifiable
# 2  "Our VP: 'I can only hit this bong 1 more time...                   other
# 3  Is this real? I feel like it might be a deep f...                   other
# 4  "The deepfake that Jack Posobiec made of Presi...  political_interference
#
#                                   communication_goal               core_frame  \
# 0                                          education           human_interest
# 1               satire,entertainment,harm_reputation           human_interest
# 2               satire,entertainment,harm_reputation           human_interest
# 3               satire,entertainment,harm_reputation  conflict,human_interest
# 4  entertainment,harm_political_interference,acti...  responsibility,conflict
#
#                                                 hero  \
# 0                                          Joe Biden
# 1  A Leader Who Sounds Smart and Capable During S...
# 2  Intelligent Manner. and People Expect That A C...
# 3  His Squad To Dress In Drag. and The Freedom Fo...
# 4    Poso'S Supposters, Those Who Share His Ideology
#
#                                              villain  \
# 0                                              Putin
# 1  Kamala Harris Rambling and Not Making Sense Du...
# 2     Online Users Believe That Harris Is A Rambler.
# 3                  Republicans Who Want To Ban Drag.
# 4  Aoc, and Other Related Gov. Officials Who Shar...
#
#                                                 plot  \
# 0                           Putin and Biden hugging
# 1  Kamala's speech does not make sense, which lea...
# 2  Kamala Harris is shown to be giving a speech t...
# 3  Republicans want to ban drag, but Donald Trump...
# 4  Biden and AOC do not understand how to priorit...
#
#                                                moral            domain    year
# 0            U.S. and Russian leaders can get along        twitter.com  2023.0
# 1  Kamala Harris's credibility as VP should be qu...       twitter.com  2023.0
# 2  Kamala Harris is portrayed as being unable to ...  www.facebook.com  2023.0
# 3  Republicans should stop calling for drag to be...       twitter.com  2023.0
# 4  we must take a stand against their choices to ...       twitter.com  2023.0
#
# [5 rows x 60 columns]

# %%
symbol_df = pd.read_csv('symbols_detected_over_090_detailed.csv')
symbol_df.head()
# Out:
#       image      detected_symbols
# 0   994.png            ['police']
# 1  670.jpeg  ['communist symbol']
# 2  148.jpeg          ['prisoner']
# 3  180.jpeg          ['prisoner']
# 4  153.jpeg          ['prisoner']

# %%
symbol_df["incident_id"] = symbol_df["image"].str.extract(r"(\d+)")
symbol_df["incident_id"] = symbol_df["incident_id"].astype(int)
symbol_df.head()
# Out:
#       image      detected_symbols  incident_id
# 0   994.png            ['police']          994
# 1  670.jpeg  ['communist symbol']          670
# 2  148.jpeg          ['prisoner']          148
# 3  180.jpeg          ['prisoner']          180
# 4  153.jpeg          ['prisoner']          153

# %%
merged_df = df.merge(symbol_df, on="incident_id", how="left")

# %%
merged_df.head()
# Out:
#    Unnamed: 0  incident_id report_id  date_coded  \
# 0           0          203        17  2024-02-12
# 1           1          186        18  2024-02-04
# 2           2          187        19  2024-02-05
# 3           3          188        20  2024-02-05
# 4           4          201        25  2024-02-09
#
#                                                  url  \
# 0  https://twitter.com/DouglasLucas/status/171631...
# 1  https://twitter.com/21WIRE/status/165300993699...
# 2      https://www.facebook.com/reel/894486844951526
# 3  https://twitter.com/JebraFaushay/status/165937...
# 4  https://twitter.com/JackPosobiec/status/163383...
#
#                                                 file screenshot date_posted  \
# 0  Screenshot 2024-02-12 at 12.47.24 PM.png (http...        NaN  2023-10-23
# 1  "Patrick Henningsen on X_ _⭕️ Granted, this mu...        NaN  2023-05-01
# 2  deepfake 19.html (https://v5.airtableuserconte...        NaN  2023-05-03
# 3  Deepfake 20.html (https://v5.airtableuserconte...        NaN  2023-05-18
# 4  Screenshot 2024-02-09 134519.png (https://v5.a...        NaN  2023-03-09
#
#   format                                         transcript  ...  \
# 0  image                                                NaN  ...
# 1  video  "Today is today, and yesterday was today yeste...  ...
# 2  video  “Today is today, and yesterday is today yester...  ...
# 3  video  "Excuse me, excuse me. I need everyone in the ...  ...
# 4  video  I'll tell you something the deepfake that Jack...  ...
#
#                                   communication_goal               core_frame  \
# 0                                          education           human_interest
# 1               satire,entertainment,harm_reputation           human_interest
# 2               satire,entertainment,harm_reputation           human_interest
# 3               satire,entertainment,harm_reputation  conflict,human_interest
# 4  entertainment,harm_political_interference,acti...  responsibility,conflict
#
#                                                 hero  \
# 0                                          Joe Biden
# 1  A Leader Who Sounds Smart and Capable During S...
# 2  Intelligent Manner. and People Expect That A C...
# 3  His Squad To Dress In Drag. and The Freedom Fo...
# 4    Poso'S Supposters, Those Who Share His Ideology
#
#                                              villain  \
# 0                                              Putin
# 1  Kamala Harris Rambling and Not Making Sense Du...
# 2     Online Users Believe That Harris Is A Rambler.
# 3                  Republicans Who Want To Ban Drag.
# 4  Aoc, and Other Related Gov. Officials Who Shar...
#
#                                                 plot  \
# 0                           Putin and Biden hugging
# 1  Kamala's speech does not make sense, which lea...
# 2  Kamala Harris is shown to be giving a speech t...
# 3  Republicans want to ban drag, but Donald Trump...
# 4  Biden and AOC do not understand how to priorit...
#
#                                                moral            domain  \
# 0            U.S. and Russian leaders can get along        twitter.com
# 1  Kamala Harris's credibility as VP should be qu...       twitter.com
# 2  Kamala Harris is portrayed as being unable to ...  www.facebook.com
# 3  Republicans should stop calling for drag to be...       twitter.com
# 4  we must take a stand against their choices to ...       twitter.com
#
#      year image detected_symbols
# 0  2023.0   NaN              NaN
# 1  2023.0   NaN              NaN
# 2  2023.0   NaN              NaN
# 3  2023.0   NaN              NaN
# 4  2023.0   NaN              NaN
#
# [5 rows x 62 columns]

# %%
from collections import Counter

all_symbols = merged_df['detected_symbols'].dropna().explode()
symbol_counts = all_symbols.value_counts()
print(symbol_counts)
# Out:
# detected_symbols
# ['prisoner']                        33
# ['communist symbol']                32
# ['army']                            31
# ['police']                          30
# ['american flag']                   21
# ['army', 'communist symbol']         6
# ['rainbow pride flag']               4
# ['police', 'prisoner']               2
# ['rainbow pride flag', 'police']     1
# ['communist symbol', 'prisoner']     1
# Name: count, dtype: int64

# %%
import pandas as pd
import ast
# Assume merged_df is your merged DataFrame

# Step 1: Explode the 'detected_symbols' list into individual rows
merged_df['detected_symbols'] = merged_df['detected_symbols'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# Now explode the list into individual symbols
exploded_df = merged_df.explode('detected_symbols')

# Count individual symbol frequencies
symbol_counts = exploded_df['detected_symbols'].value_counts()
print(symbol_counts)

# Step 3: Analyze each symbol against other fields (example: 'villain')
symbol_vs_villain = exploded_df.groupby(['detected_symbols', 'villain']).size().unstack(fill_value=0)
symbol_vs_domain = exploded_df.groupby(['detected_symbols', 'domain']).size().unstack(fill_value=0)
symbol_vs_hero = exploded_df.groupby(['detected_symbols', 'hero']).size().unstack(fill_value=0)
symbol_vs_year = exploded_df.groupby(['detected_symbols', 'year']).size().unstack(fill_value=0)
symbol_vs_goal = exploded_df.groupby(['detected_symbols', 'communication_goal']).size().unstack(fill_value=0)


import matplotlib.pyplot as plt

symbol_counts.plot(kind='bar', title='Frequency of Detected Symbols')
plt.ylabel('Number of Incidents')
plt.xlabel('Symbol')
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()
# Out:
# detected_symbols
# communist symbol      39
# army                  37
# prisoner              36
# police                33
# american flag         21
# rainbow pride flag     5
# Name: count, dtype: int64

# %%
print("Symbol vs Villain:\n", symbol_vs_villain)
print("\nSymbol vs Domain:\n", symbol_vs_domain)
print("\nSymbol vs Hero:\n", symbol_vs_hero)
print("\nSymbol vs Year:\n", symbol_vs_year)
print("\nSymbol vs Communication Goal:\n", symbol_vs_goal)
# Out:
# Symbol vs Villain:
#  villain             Aoc  Deceptive Ai Images  Donald Trump  Grok 2  \
# detected_symbols
# american flag         1                    1             2       1
# army                  0                    0             4       0
# communist symbol      0                    0             4       0
# police                0                    0            12       0
# prisoner              0                    0            23       0
# rainbow pride flag    0                    0             1       0
#
# villain             Harris-Walz Campaign  Joe Biden  Kamala Harris  Na  \
# detected_symbols
# american flag                          1          1              1   1
# army                                   0          3             17   0
# communist symbol                       0          0             22   0
# police                                 0          0              2   0
# prisoner                               0          0              2   0
# rainbow pride flag                     0          0              0   0
#
# villain             People That Do Not Like Her.  \
# detected_symbols
# american flag                                  1
# army                                           0
# communist symbol                               0
# police                                         0
# prisoner                                       0
# rainbow pride flag                             0
#
# villain             People That Do Not Like Them.  ...  \
# detected_symbols                                   ...
# american flag                                   1  ...
# army                                            0  ...
# communist symbol                                0  ...
# police                                          0  ...
# prisoner                                        0  ...
# rainbow pride flag                              0  ...
#
# villain             Donald Trump Has Escaped Prison  \
# detected_symbols
# american flag                                     0
# army                                              0
# communist symbol                                  0
# police                                            0
# prisoner                                          1
# rainbow pride flag                                0
#
# villain             Donald Trump Is Evading Justice  \
# detected_symbols
# american flag                                     0
# army                                              0
# communist symbol                                  0
# police                                            0
# prisoner                                          1
# rainbow pride flag                                0
#
# villain             Donald Trump and Kamala Harris  Hilary Clinton  \
# detected_symbols
# american flag                                    0               0
# army                                             0               0
# communist symbol                                 0               0
# police                                           0               0
# prisoner                                         1               3
# rainbow pride flag                               0               0
#
# villain             Prison/The Gym  What Is Depicted In The Deepfake/Trump  \
# detected_symbols
# american flag                    0                                       0
# army                             0                                       0
# communist symbol                 0                                       0
# police                           0                                       0
# prisoner                         1                                       2
# rainbow pride flag               0                                       0
#
# villain             Anti-Lgbtq Rhetoric and Musk Supporting Trump  Mike Pence  \
# detected_symbols
# american flag                                                   0           0
# army                                                            0           0
# communist symbol                                                0           0
# police                                                          0           0
# prisoner                                                        0           0
# rainbow pride flag                                              1           1
#
# villain             Pence  \
# detected_symbols
# american flag           0
# army                    0
# communist symbol        0
# police                  0
# prisoner                0
# rainbow pride flag      1
#
# villain             Trump Reposting Numerous Deepfakes On His Social Media Accounts.
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            0
# rainbow pride flag                                                  1
#
# [6 rows x 50 columns]
#
# Symbol vs Domain:
#  domain              truthsocial.com  www.facebook.com  x.com  \
# detected_symbols
# american flag                     2                 1     18
# army                              0                 0     33
# communist symbol                  0                 0     38
# police                            0                 0      7
# prisoner                          0                 0      7
# rainbow pride flag                0                 0      4
#
# domain              farid.berkeley.edu  twitter.com  www.news.com.au
# detected_symbols
# american flag                        0            0                0
# army                                 2            1                0
# communist symbol                     0            1                0
# police                               0           25                0
# prisoner                             0           28                1
# rainbow pride flag                   0            1                0
#
# Symbol vs Hero:
#  hero                Donald Trump  Donald Trump and Elon Musk  \
# detected_symbols
# american flag                 11                           2
# army                          15                           0
# communist symbol              12                           0
# police                         3                           0
# prisoner                       5                           0
# rainbow pride flag             0                           0
#
# hero                Donald Trump and Kamala Harris  Israel  Kamala Harris  \
# detected_symbols
# american flag                                    1       1              2
# army                                             0       0              7
# communist symbol                                 1       0              6
# police                                           0       0              1
# prisoner                                         0       0              0
# rainbow pride flag                               0       0              0
#
# hero                Trump Winning The Election  Trump-Vance Campaign  \
# detected_symbols
# american flag                                1                     1
# army                                         0                     0
# communist symbol                             0                     0
# police                                       0                     0
# prisoner                                     0                     0
# rainbow pride flag                           0                     0
#
# hero                Understanding The Capabilities Of Ai  \
# detected_symbols
# american flag                                          1
# army                                                   0
# communist symbol                                       0
# police                                                 0
# prisoner                                               0
# rainbow pride flag                                     0
#
# hero                Donald Trump (Or Anti-Harris People)  \
# detected_symbols
# american flag                                          0
# army                                                   2
# communist symbol                                       0
# police                                                 0
# prisoner                                               0
# rainbow pride flag                                     0
#
# hero                Donald Trump Is Probably The Hero  ...  Michael Cohen  \
# detected_symbols                                       ...
# american flag                                       0  ...              0
# army                                                1  ...              0
# communist symbol                                    0  ...              0
# police                                              0  ...              0
# prisoner                                            0  ...              1
# rainbow pride flag                                  0  ...              0
#
# hero                No One  The Government/Prison Wardens  \
# detected_symbols
# american flag            0                              0
# army                     0                              0
# communist symbol         0                              0
# police                   0                              0
# prisoner                 1                              2
# rainbow pride flag       0                              0
#
# hero                The Imprisonment Of Donald Trump  The Justice System  \
# detected_symbols
# american flag                                      0                   0
# army                                               0                   0
# communist symbol                                   0                   0
# police                                             0                   0
# prisoner                                           3                  12
# rainbow pride flag                                 0                   0
#
# hero                Those Judicially Responsible For Indicting Trump and Us Government  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            2
# rainbow pride flag                                                  0
#
# hero                Us Government, Anyone Against Trump  AI  \
# detected_symbols
# american flag                                         0   0
# army                                                  0   0
# communist symbol                                      0   0
# police                                                0   0
# prisoner                                              1   0
# rainbow pride flag                                    0   1
#
# hero                Lgbtq Rights and Musk Supporting Harris  \
# detected_symbols
# american flag                                             0
# army                                                      0
# communist symbol                                          0
# police                                                    0
# prisoner                                                  0
# rainbow pride flag                                        1
#
# hero                Not Posting Deepfakes.
# detected_symbols
# american flag                            0
# army                                     0
# communist symbol                         0
# police                                   0
# prisoner                                 0
# rainbow pride flag                       1
#
# [6 rows x 57 columns]
#
# Symbol vs Year:
#  year                2023.0  2024.0
# detected_symbols
# american flag            0      21
# army                     0      37
# communist symbol         1      38
# police                  29       4
# prisoner                29       7
# rainbow pride flag       3       2
#
# Symbol vs Communication Goal:
#  communication_goal  activism  activism,education  boost_reputation  \
# detected_symbols
# american flag              1                   1                 1
# army                       0                   0                 0
# communist symbol           0                   0                 0
# police                     1                   0                 0
# prisoner                   0                   0                 0
# rainbow pride flag         0                   0                 0
#
# communication_goal  boost_reputation,entertainment,satire  \
# detected_symbols
# american flag                                           1
# army                                                    0
# communist symbol                                        0
# police                                                  0
# prisoner                                                0
# rainbow pride flag                                      0
#
# communication_goal  boost_reputation,false_info  education  entertainment  \
# detected_symbols
# american flag                                 1          1              1
# army                                          0          1              1
# communist symbol                              0          2              0
# police                                        0          0              0
# prisoner                                      0          1              1
# rainbow pride flag                            0          0              0
#
# communication_goal  entertainment,education  entertainment,satire  false_info  \
# detected_symbols
# american flag                             3                     1           3
# army                                      0                     0           0
# communist symbol                          0                     0           1
# police                                    0                     0           0
# prisoner                                  0                     0           0
# rainbow pride flag                        0                     0           0
#
# communication_goal  ...  satire,entertainment,harm_reputation  \
# detected_symbols    ...
# american flag       ...                                     0
# army                ...                                     0
# communist symbol    ...                                     0
# police              ...                                    10
# prisoner            ...                                    17
# rainbow pride flag  ...                                     0
#
# communication_goal  satire,false_info,harm_political_interference,harm_reputation  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              1
# prisoner                                                            0
# rainbow pride flag                                                  0
#
# communication_goal  satire,harm_violence,harm_reputation  \
# detected_symbols
# american flag                                          0
# army                                                   0
# communist symbol                                       0
# police                                                 1
# prisoner                                               0
# rainbow pride flag                                     0
#
# communication_goal  diversion_flooding,entertainment,harm_reputation,harm_emotional_psychological,activism  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            1
# rainbow pride flag                                                  0
#
# communication_goal  entertainment,diversion_flooding,activism,harm_reputation  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            1
# rainbow pride flag                                                  0
#
# communication_goal  entertainment,harm_reputation,harm_political_interference  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            1
# rainbow pride flag                                                  0
#
# communication_goal  entertainment,satire,harm_reputation  \
# detected_symbols
# american flag                                          0
# army                                                   0
# communist symbol                                       0
# police                                                 0
# prisoner                                               1
# rainbow pride flag                                     0
#
# communication_goal  harm_reputation,satire  \
# detected_symbols
# american flag                            0
# army                                     0
# communist symbol                         0
# police                                   0
# prisoner                                 1
# rainbow pride flag                       1
#
# communication_goal  satire,entertainment,harm_political_interference,harm_reputation  \
# detected_symbols
# american flag                                                       0
# army                                                                0
# communist symbol                                                    0
# police                                                              0
# prisoner                                                            1
# rainbow pride flag                                                  0
#
# communication_goal  harm_reputation,false_info,satire
# detected_symbols
# american flag                                       0
# army                                                0
# communist symbol                                    0
# police                                              0
# prisoner                                            0
# rainbow pride flag                                  1
#
# [6 rows x 62 columns]

# %%
import matplotlib.pyplot as plt

# Step 1: Keep all symbols
# (Nothing to filter here)

# Step 2: Helper to limit secondary categories (top 10 values)
def filter_top_categories(df, group_col, top_n=10):
    top_values = df[group_col].value_counts().nlargest(top_n).index
    return df[df[group_col].isin(top_values)]

# Step 3: Filter only the second dimension (villain, domain, etc.)
villain_df = filter_top_categories(exploded_df, 'villain')
domain_df = filter_top_categories(exploded_df, 'domain')
hero_df = filter_top_categories(exploded_df, 'hero')
goal_df = filter_top_categories(exploded_df, 'communication_goal')

# Step 4: Group the data
symbol_vs_villain = villain_df.groupby(['detected_symbols', 'villain']).size().unstack(fill_value=0)
symbol_vs_domain = domain_df.groupby(['detected_symbols', 'domain']).size().unstack(fill_value=0)
symbol_vs_hero = hero_df.groupby(['detected_symbols', 'hero']).size().unstack(fill_value=0)
symbol_vs_year = exploded_df.groupby(['detected_symbols', 'year']).size().unstack(fill_value=0)  # all years
symbol_vs_goal = goal_df.groupby(['detected_symbols', 'communication_goal']).size().unstack(fill_value=0)

# Step 5: Plotting function
def plot_symbol_relationship(df, title, xlabel, ylabel='Count'):
    df.plot(kind='bar', stacked=True, figsize=(12, 6))
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Step 6: Plot
plot_symbol_relationship(symbol_vs_villain, 'Detected Symbols vs Villains', 'Detected Symbol')
plot_symbol_relationship(symbol_vs_domain, 'Detected Symbols vs Domains', 'Detected Symbol')
plot_symbol_relationship(symbol_vs_hero, 'Detected Symbols vs  Heroes', 'Detected Symbol')
plot_symbol_relationship(symbol_vs_year, 'Detected Symbols vs Year', 'Detected Symbol')
plot_symbol_relationship(symbol_vs_goal, 'Detected Symbols vs Communication Goals', 'Detected Symbol')

# %%
import seaborn as sns
sns.heatmap(symbol_vs_villain, annot=True, cmap="YlGnBu")
# Out:
# <Axes: xlabel='villain', ylabel='detected_symbols'>

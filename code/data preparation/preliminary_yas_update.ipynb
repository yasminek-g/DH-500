# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
display(df.head())

print("Number of columns:", len(df.columns.tolist()))
for col in df.columns.tolist():
    print(col)
# Out:
#    incident_id report_id  thread Validated By Title Tags  date_coded  \
# 0           74         2     NaN          NaN   NaN  NaN  2023-10-29
# 1           75         3     NaN          NaN   NaN  NaN  2023-10-29
# 2           76         4     NaN          NaN   NaN  NaN  2023-10-29
# 3           70         5     NaN          NaN   NaN  NaN  2023-10-23
# 4           77         6     NaN          NaN   NaN  NaN  2023-10-29
#
#                                                  url source file  ...  \
# 0  https://twitter.com/MikaelThalen/status/150412...    NaN  NaN  ...
# 1  https://twitter.com/ThePatriotOasis/status/163...    NaN  NaN  ...
# 2  https://twitter.com/SabrinaHalper/status/17136...    NaN  NaN  ...
# 3  https://twitter.com/MechaOrvo/status/171479783...    NaN  NaN  ...
# 4  https://twitter.com/NotPoliticians/status/1714...    NaN  NaN  ...
#
#                                               hero  \
# 0                              Ukrainian soldiers
# 1  The US military/ freedom for Ukraine and Taiwan
# 2                                    Warren Buffet
# 3                      Trump for denouncing Israel
# 4                                   AI regulations
#
#   Needs External Review (Hero)                                    villain  \
# 0                          NaN  Ukrainain soliders are dying in the war.
# 1                          NaN                          China and Russia
# 2                          NaN                        Economic inequality
# 3                          NaN                              Israel and US
# 4                          NaN                       Lack of regulations
#
#   Needs External Review (Villain)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                                                 plot  \
# 0  President Zelensky is calling for troops to st...
# 1  Increased tensions in Ukraine and Taiwan have ...
# 2  Warren Buffet is wanting to give away some of ...
# 3         Trump is denouncing the actions of Israel.
# 4  AI is being used to create pThe current lack o...
#
#   Needs External Review (Plot)  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                                moral  \
# 0  Zelenksy thinks Ukraine is losing the war so h...
# 1  The opening of the draft is inevitable due to ...
# 2  Warren Buffet thinks giving his money away to ...
# 3                Trump is standing up for Palestine.
# 4  AI is being used to create political ads that ...
#
#   Needs External Review (Moral)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                            comments_policy_narrative Validated
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  Images could be interpreted as Macron being th...       NaN
# 4                                                NaN       NaN
#
# [5 rows x 191 columns]
# Number of columns: 191
# incident_id
# report_id
# thread
# Validated By
# Title
# Tags
# date_coded
# url
# source
# file
# file_with_watermark
# screenshot
# date_posted
# format
# transcript
# summary_content
# type
# comment_type
# Needs external review (type)
# HiveModeration_Score
# sharer_faketype
# Needs External Review (sharer_faketype)
# external_verification
# Needs External Review (external_verification)
# links_verification
# evidence_fake
# watermark
# Needs External Verification (watermark)
# likes
# views
# comments
# shares
# original_source_name
# original_source_username
# Needs External Review (Original Source Name)
# original_source_type
# Needs External Review (Original Source Type)
# original_source_actor_type
# Needs External Review (Original Source Actor Type)
# original_source_country
# other_original_source_country
# Needs External Review (Original Source Country)
# comments_coding_original_source
# sharer_name
# other_sharer_name
# Needs External Review (Sharer Name)
# sharer_username
# sharer_type
# Needs External Review (Sharer Type)
# sharer_job
# Needs External Review (Sharer Job)
# high_impact_comment
# sharer_country
# other_sharer_country
# Needs External Review (Sharer Country)
# sharer_city
# other_sharer_city
# Needs External Review (Sharer City)
# comments_sharer_coding
# target_name
# target_one_name
# target_one_name_other
# target_one_sentiment
# target_one_type_macro
# target_one_type_micro
# target_one_country
# target_one_country_other
# target_one_responded
# target_one_response
# target_two_name
# target_two_name_other
# target_two_sentiment
# target_two_type_macro
# target_two_type_micro
# target_two_country
# target_two_country_other
# target_two_responded
# target_two_response
# target_three_name
# target_three_name_other
# target_three_sentiment
# target_three_type_macro
# target_three_type_micro
# target_three_country
# target_three_country_other
# target_three_responded
# target_three_response
# target_four_name
# target_four_name_other
# target_four_sentiment
# target_four_type_macro
# target_four_type_micro
# target_four_country
# target_four_country_other
# target_four_responded
# target_four_response
# target_five_name
# target_five_name_other
# target_five_sentiment
# target_five_type_macro
# target_five_type_micro
# target_five_country
# target_five_country_other
# target_five_responded
# target_five_response
# target_six_name
# target_six_name_other
# target_six_sentiment
# target_six_type_macro
# target_six_type_micro
# target_six_country
# target_six_country_other
# target_six_responded
# target_six_response
# target_seven_name
# target_seven_name_other
# target_seven_sentiment
# target_seven_type_macro
# target_seven_type_micro
# target_seven_country
# target_seven_country_other
# target_seven_responded
# target_seven_response
# target_eight_name
# target_eight_name_other
# target_eight_sentiment
# target_eight_type_macro
# target_eight_type_micro
# target_eight_country
# target_eight_country_other
# target_eight_responded
# target_eight_response
# target_nine_name
# target_nine_name_other
# target_nine_sentiment
# target_nine_type_macro
# target_nine_type_micro
# target_nine_country
# target_nine_country_other
# target_nine_responded
# target_nine_response
# target_ten_name
# target_ten_name_other
# target_ten_sentiment
# target_ten_type_macro
# target_ten_type_micro
# target_ten_country
# target_ten_country_other
# target_ten_responded
# target_ten_response
# Needs External Review (Target Name)
# target_type_macro
# Needs External Review (Target Type Macro)
# target_type_micro
# Needs External Review (Target Type Micro)
# target_country
# other_target_country
# Needs External Review (Target Country)
# target_responded
# comments_target_coding
# target_response
# deepfake_content_depicts
# Needs External Review (Content Depicts)
# harm_depicted
# Needs External Review (Harm Depicted)
# comments_content_topic
# social_policy_sector
# Needs External Review (Social Policy Sector)
# comments_social_policy_sector
# context_deepfake
# Needs External Review (Context Deepfake)
# text_around_deepfake
# harm_evidence
# Needs External Review (Harm Evidence)
# comments_harms_context
# communication_goal
# Needs External Review (Communication Goal)
# comments_communication_goal
# core_frame
# Needs External Review (Core Frame)
# comments_core_frame
# hero
# Needs External Review (Hero)
# villain
# Needs External Review (Villain)
# plot
# Needs External Review (Plot)
# moral
# Needs External Review (Moral)
# comments_policy_narrative
# Validated

# %% [markdown]
# A lot of columns; check for which ones are redundant (almost all NaN). Find most relevant ones.
# (We can be a bit more aggressive here, removing all with >80% NaN)

# %%
all_nan_cols = df.columns[df.isna().all()]
print("Columns with all NaN values:", len(list(all_nan_cols)))

threshold = 0.80
high_nan_cols = df.columns[df.isna().mean() > threshold]
print("Columns with more than 80% NaN values:", len(list(high_nan_cols)))

# Find most relevant columns
df_relevant = df.drop(columns=high_nan_cols)
print("\nRemaining columns:", len(df_relevant.columns.to_list()))
for relev in df_relevant.columns.to_list():
    print(relev)
# Out:
# Columns with all NaN values: 61
# Columns with more than 80% NaN values: 134
#
# Remaining columns: 57
# incident_id
# report_id
# date_coded
# url
# file
# screenshot
# date_posted
# format
# transcript
# summary_content
# type
# comment_type
# sharer_faketype
# external_verification
# links_verification
# evidence_fake
# watermark
# likes
# views
# comments
# shares
# original_source_name
# original_source_type
# original_source_actor_type
# original_source_country
# sharer_name
# sharer_type
# sharer_job
# high_impact_comment
# sharer_country
# sharer_city
# target_name
# target_one_name
# target_one_sentiment
# target_one_type_macro
# target_one_type_micro
# target_one_country
# target_two_name
# target_two_sentiment
# target_two_type_macro
# target_two_type_micro
# target_two_country
# target_type_macro
# target_type_micro
# target_country
# deepfake_content_depicts
# harm_depicted
# social_policy_sector
# context_deepfake
# text_around_deepfake
# harm_evidence
# communication_goal
# core_frame
# hero
# villain
# plot
# moral

# %% [markdown]
# ## Social platforms

# %%
from urllib.parse import urlparse

# Determine social platform by extracting the domain from the URL
df['domain'] = df['url'].apply(lambda x: urlparse(x).netloc if pd.notnull(x) else None)
print("Social platform counts:\n", df['domain'].value_counts())
# Out:
# Social platform counts:
#  domain
# x.com                                     601
# twitter.com                               159
# www.tiktok.com                             39
# youtu.be                                   31
# www.youtube.com                            22
# www.instagram.com                          18
# miro.medium.com                            16
# www.facebook.com                           14
# farid.berkeley.edu                         12
# www.reddit.com                              8
# truthsocial.com                             7
# archive.is                                  6
#                                             4
# web.archive.org                             3
# www.cnn.com                                 3
# www.alternet.org                            3
# techcrunch.com                              3
# nypost.com                                  2
# archive.li                                  2
# static01.nytimes.com                        2
# www.theguardian.com                         1
# m.independent.ie                            1
# www.news.com.au                             1
# www.politico.com                            1
# www.reuters.com                             1
# static01.nyt.com                            1
# tungsten.run                                1
# www.washingtonpost.com                      1
# www.reforma.com                             1
# archive.ph                                  1
# perma.cc                                    1
# www.snopes.com                              1
# untappedcities.com                          1
# thumbnails.texastribune.org                 1
# creator.nightcafe.studio                    1
# www-dailymail-co-uk.cdn.ampproject.org      1
# www.twitch.tv                               1
# Name: count, dtype: int64

# %% [markdown]
# We can see that the most popular deepfake/cheapfake platforms are X/Twitter, TikTok, YouTube, Instagram and Facebook. We have some other websites to explore too, such as Medium, Berkeley and TruthSocial, etc.

# %%
# Count rows per year in the date_posted column
df['date_posted'] = pd.to_datetime(df['date_posted'], errors='coerce')
df['year'] = df['date_posted'].dt.year
print("Rows per year:\n", df['year'].value_counts())
# Out:
# Rows per year:
#  year
# 2024.0    617
# 2023.0    240
# 2020.0     52
# 2021.0     35
# 2022.0     16
# 2019.0      9
# 2018.0      2
# 2016.0      1
# 2025.0      1
# Name: count, dtype: int64

# %% [markdown]
# We see that most posts were made in 2024 and 2023, which can provide a sufficient basis for our analysis (857 rows).

# %%
# Identify rows with media
media_rows = df[df['file'].notna()]
print("Number of rows with media:", media_rows.shape[0])
print("Proportion with media:", media_rows.shape[0]/len(df))
# Out:
# Number of rows with media: 928
# Proportion with media: 0.9508196721311475

# %% [markdown]
# Around 95% of the rows have media, which is promising for some image processing analysis.

# %%
print("Format counts:\n", df['format'].value_counts())
print("\nType counts:\n", df['type'].value_counts())
print("\nSharer faketype counts:\n", df['sharer_faketype'].value_counts())
print("\nExternal verification counts:\n", df['external_verification'].value_counts())
# Out:
# Format counts:
#  format
# image    646
# video    330
# Name: count, dtype: int64
#
# Type counts:
#  type
# deepfake           803
# unclear/unknown     89
# cheapfake           82
# real                 1
# Name: count, dtype: int64
#
# Sharer faketype counts:
#  sharer_faketype
# fake              468
# unclear           350
# real_authentic    157
# Name: count, dtype: int64
#
# External verification counts:
#  external_verification
# unknown                  455
# verified_fake            325
# authenticity_disputed    156
# verified_real             39
# Name: count, dtype: int64

# %% [markdown]
# The majority of media is images with a significant portion of videos. We have enough on deepfakes to fully focus on it (and not worry about the nuances/differences between deepfakes and cheapfakes, etc). Most of the sharers of these posts deem their posts to be fake, but an equally significant portion does not explicitly state anything (350 sharers being unclear). Huge lack of external verification which can be a potential weakness.

# %% [markdown]
# # Potential ways to filter the data
#
# We will also filter away all the high-NaN columns as well for all options.

# %%
df = df.drop(columns=high_nan_cols)

# %% [markdown]
# ### 1. 2023-2024 analysis of deepfake images/videos that have been verified

# %%
df1 = df[
    (df['year'].isin([2023, 2024])) &
    (df['type'] == 'deepfake') &
    (df['file'].notna()) &
    (df['external_verification'] != 'unknown')
]

# %%
print(df1.shape)
display(df1)
# Out:
# (340, 59)
#      incident_id report_id  date_coded  \
# 16           203        17  2024-02-12
# 18           186        18  2024-02-04
# 20           187        19  2024-02-05
# 31           201        25  2024-02-09
# 32           283        26  2024-03-04
# ..           ...       ...         ...
# 917         1002       543  2025-03-04
# 925         1011       444  2025-03-05
# 957         1044       594  2025-03-05
# 958         1045       533  2025-03-05
# 960         1047       543  2025-03-05
#
#                                                    url  \
# 16   https://twitter.com/DouglasLucas/status/171631...
# 18   https://twitter.com/21WIRE/status/165300993699...
# 20       https://www.facebook.com/reel/894486844951526
# 31   https://twitter.com/JackPosobiec/status/163383...
# 32   https://www.reddit.com/r/ChatGPT/comments/156h...
# ..                                                 ...
# 917  https://x.com/cattocrunch/status/1825860652847...
# 925  https://x.com/realDonaldTrump/status/182406968...
# 957  https://x.com/Jere_Memez/status/18250285930359...
# 958  https://x.com/YourMomsHo42215/status/182532763...
# 960  https://x.com/cattocrunch/status/1825860652847...
#
#                                                   file  \
# 16   Screenshot 2024-02-12 at 12.47.24 PM.png (http...
# 18   "Patrick Henningsen on X_ _⭕️ Granted, this mu...
# 20   deepfake 19.html (https://v5.airtableuserconte...
# 31   Screenshot 2024-02-09 134519.png (https://v5.a...
# 32   deepfake 26.html (https://v5.airtableuserconte...
# ..                                                 ...
# 917  GVQyp6pWAAAk6cw.jpg (https://v5.airtableuserco...
# 925  ScreenRecording_03-05-2025 14-04-06_1.mov (htt...
# 957  pdid 594.jpg (https://v5.airtableusercontent.c...
# 958  pdid 533.jpg (https://v5.airtableusercontent.c...
# 960  GVQyp6pWAAAk6cw.jpg (https://v5.airtableuserco...
#
#                                             screenshot date_posted format  \
# 16                                                 NaN  2023-10-23  image
# 18                                                 NaN  2023-05-01  video
# 20                                                 NaN  2023-05-03  video
# 31                                                 NaN  2023-03-09  video
# 32                                                 NaN  2023-07-22  video
# ..                                                 ...         ...    ...
# 917  Screenshot 2025-03-03 210934.png (https://v5.a...  2024-08-20  image
# 925  Screenshot 2025-03-05 at 2.04.31 PM.png (https...  2024-08-15  video
# 957  Screenshot 2024-10-30 at 12.54.40 PM.png (http...  2024-08-18  image
# 958  Screen Shot 2025-03-05 at 4.05.44 PM.png (http...  2024-08-18  image
# 960  Screenshot 2025-03-03 210934.png (https://v5.a...  2024-08-20  image
#
#                                             transcript  \
# 16                                                 NaN
# 18   "Today is today, and yesterday was today yeste...
# 20   “Today is today, and yesterday is today yester...
# 31   I'll tell you something the deepfake that Jack...
# 32   "Highly anticipated season for reloaded update...
# ..                                                 ...
# 917                                                NaN
# 925  Stayin' Alive by the Bee Gees is playing in th...
# 957                                                NaN
# 958                                                NaN
# 960                                                NaN
#
#                                        summary_content  ...  \
# 16   Two polaroid photographs, the one one the righ...  ...
# 18   Kamala Harris is speaking at a rally and her s...  ...
# 20   The sharer posted a video showing her reacting...  ...
# 31   AOC announcing her opinions with regards to ho...  ...
# 32   The video shows a news clip from Tucker Carlso...  ...
# ..                                                 ...  ...
# 917  The image depicts Donald Trump standing in an ...  ...
# 925         Donald Trump and Elon Musk are dancing. \n  ...
# 957  It is a screenshot of Donald Trump's post of K...  ...
# 958  It is an image of Taylor Swift dressed in a ty...  ...
# 960  The image depicts Donald Trump standing in an ...  ...
#
#                                   text_around_deepfake  \
# 16   AI and the end of photographic truth? Deceptiv...
# 18   ⭕️ Granted, this must be a deep fake, but rega...
# 20   "Our VP: 'I can only hit this bong 1 more time...
# 31   "The deepfake that Jack Posobiec made of Presi...
# 32   ChatGPT wrote ALL the words coming out of this...
# ..                                                 ...
# 917  The caption says: "holy shit man look at these...
# 925                                               NA\n
# 957                                                NaN
# 958  Sharer: "Imagine the group that says “Kamala h...
# 960  The caption says: "holy shit man look at these...
#
#                            harm_evidence  \
# 16                political_interference
# 18                      non_identifiable
# 20                                 other
# 31                political_interference
# 32                      non_identifiable
# ..                                   ...
# 917               political_interference
# 925                     non_identifiable
# 957               political_interference
# 958  political_interference,human_rights
# 960               political_interference
#
#                                     communication_goal  \
# 16                                           education
# 18                satire,entertainment,harm_reputation
# 20                satire,entertainment,harm_reputation
# 31   entertainment,harm_political_interference,acti...
# 32   satire,entertainment,harm_emotional_psychological
# ..                                                 ...
# 917                               satire,entertainment
# 925                               entertainment,satire
# 957  harm_political_interference,false_info,harm_re...
# 958        harm_reputation,harm_political_interference
# 960                               satire,entertainment
#
#                         core_frame  \
# 16                  human_interest
# 18                  human_interest
# 20                  human_interest
# 31         responsibility,conflict
# 32                  human_interest
# ..                             ...
# 917                 human_interest
# 925                 human_interest
# 957                 human_interest
# 958  human_interest,responsibility
# 960                 human_interest
#
#                                                   hero  \
# 16                                               Biden
# 18   A leader who sounds smart and capable during s...
# 20   People expect that a VP can communicate with c...
# 31     Poso's supposters, those who share his ideology
# 32                                                 NaN
# ..                                                 ...
# 917                                       Donald Trump
# 925                         Donald Trump and Elon Musk
# 957                                                NaN
# 958                                            unknown
# 960                                                NaN
#
#                                                villain  \
# 16                                               Putin
# 18   Kamala Harris rambling and not making sense du...
# 20     Online users believe that Harris is a rambler.
# 31   AOC, and other related gov. officials who shar...
# 32                          ChatGPT and other AI tech
# ..                                                 ...
# 917                                                NaN
# 925                                                NaN
# 957                                      Kamala Harris
# 958                                       Donald Trump
# 960                                       Donald Trump
#
#                                                   plot  \
# 16                            Putin and Biden hugging
# 18   Kamala's speech does not make sense, which lea...
# 20   Kamala Harris is shown to be giving a speech t...
# 31   Biden and AOC do not understand how to priorit...
# 32   AI programs give people the ability to create ...
# ..                                                 ...
# 917  The post suggests that while some people are c...
# 925                   Trump and Musk dancing together
# 957  If Harris is elected president, she will turn ...
# 958  Unclear, but demonstrates that Donald Trump is...
# 960  The post suggests that while some people are c...
#
#                                                  moral            domain  \
# 16             U.S. and Russian leaders can get along        twitter.com
# 18   Kamala Harris's credibility as VP should be qu...       twitter.com
# 20   Kamala Harris is portrayed as being unable to ...  www.facebook.com
# 31   we must take a stand against their choices to ...       twitter.com
# 32   AI has progressed more than a lot of people re...    www.reddit.com
# ..                                                 ...               ...
# 917  AI is being used by politicians to manipulate ...             x.com
# 925  Trump and Musk work well together, so vote for...             x.com
# 957                        Vote for Trump, not Harris              x.com
# 958  AI can be used but it is important that it mus...             x.com
# 960  AI is being used by politicians to manipulate ...             x.com
#
#        year
# 16   2023.0
# 18   2023.0
# 20   2023.0
# 31   2023.0
# 32   2023.0
# ..      ...
# 917  2024.0
# 925  2024.0
# 957  2024.0
# 958  2024.0
# 960  2024.0
#
# [340 rows x 59 columns]

# %% [markdown]
# ### 2. 2023-2024 analysis of deepfake images/videos, regardless of verification

# %%
df2 = df[
    (df['year'].isin([2023, 2024])) &
    (df['type'] == 'deepfake') &
    (df['file'].notna())
]

# %%
print(df2.shape)
display(df2)
# Out:
# (714, 59)
#      incident_id report_id  date_coded  \
# 16           203        17  2024-02-12
# 18           186        18  2024-02-04
# 20           187        19  2024-02-05
# 22           188        20  2024-02-05
# 31           201        25  2024-02-09
# ..           ...       ...         ...
# 971         1058       460  2025-03-06
# 972         1059       599  2025-03-06
# 973         1060       757  2025-03-06
# 974         1061       758  2025-03-06
# 975         1062       759  2025-03-06
#
#                                                    url  \
# 16   https://twitter.com/DouglasLucas/status/171631...
# 18   https://twitter.com/21WIRE/status/165300993699...
# 20       https://www.facebook.com/reel/894486844951526
# 22   https://twitter.com/JebraFaushay/status/165937...
# 31   https://twitter.com/JackPosobiec/status/163383...
# ..                                                 ...
# 971  https://x.com/PlanetOfMemes/status/18240700394...
# 972  https://x.com/KryptoKarma2024/status/182516139...
# 973  https://x.com/Trump_History45/status/183139475...
# 974  https://x.com/Trump_History45/status/182900803...
# 975  https://x.com/Trump_History45/status/182891374...
#
#                                                   file  \
# 16   Screenshot 2024-02-12 at 12.47.24 PM.png (http...
# 18   "Patrick Henningsen on X_ _⭕️ Granted, this mu...
# 20   deepfake 19.html (https://v5.airtableuserconte...
# 22   Deepfake 20.html (https://v5.airtableuserconte...
# 31   Screenshot 2024-02-09 134519.png (https://v5.a...
# ..                                                 ...
# 971  460.png (https://v5.airtableusercontent.com/v3...
# 972  599.png (https://v5.airtableusercontent.com/v3...
# 973  pdid 757.jpg (https://v5.airtableusercontent.c...
# 974  pdid 758.jpg (https://v5.airtableusercontent.c...
# 975  pdid 759.jpg (https://v5.airtableusercontent.c...
#
#                                             screenshot date_posted format  \
# 16                                                 NaN  2023-10-23  image
# 18                                                 NaN  2023-05-01  video
# 20                                                 NaN  2023-05-03  video
# 22                                                 NaN  2023-05-18  video
# 31                                                 NaN  2023-03-09  video
# ..                                                 ...         ...    ...
# 971  Screenshot 2025-03-05 at 8.45.11 PM.png (https...  2024-08-15  image
# 972  Screenshot 2025-03-06 at 3.01.04 PM.png (https...  2024-08-18  image
# 973  Screen Shot 2025-03-06 at 3.17.43 PM.png (http...  2024-09-04  image
# 974  Screen Shot 2025-03-06 at 3.37.57 PM.png (http...  2024-08-29  image
# 975  Screen Shot 2025-03-06 at 3.54.58 PM.png (http...  2024-08-28  image
#
#                                             transcript  \
# 16                                                 NaN
# 18   "Today is today, and yesterday was today yeste...
# 20   “Today is today, and yesterday is today yester...
# 22   "Excuse me, excuse me. I need everyone in the ...
# 31   I'll tell you something the deepfake that Jack...
# ..                                                 ...
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
#
#                                        summary_content  ...  \
# 16   Two polaroid photographs, the one one the righ...  ...
# 18   Kamala Harris is speaking at a rally and her s...  ...
# 20   The sharer posted a video showing her reacting...  ...
# 22   The video shows Donald Trump, Mike Pence, and ...  ...
# 31   AOC announcing her opinions with regards to ho...  ...
# ..                                                 ...  ...
# 971  Donald Trump and Elon Musk are sitting, talkin...  ...
# 972  Donald Trump is riding a horse with eagle wing...  ...
# 973  It is a picture of Kamala Harris shaking hands...  ...
# 974  It is an image of Barack Obama's face in front...  ...
# 975  It is an image of Donald Trump dressed up as t...  ...
#
#                                   text_around_deepfake  \
# 16   AI and the end of photographic truth? Deceptiv...
# 18   ⭕️ Granted, this must be a deep fake, but rega...
# 20   "Our VP: 'I can only hit this bong 1 more time...
# 22   Is this real? I feel like it might be a deep f...
# 31   "The deepfake that Jack Posobiec made of Presi...
# ..                                                 ...
# 971     The caption says "Let's do some weekly spaces"
# 972  The caption says "@realDonaldTrump\n $RDT CTO ...
# 973  A young Kamala Harris shaking hands with commu...
# 974  Why is Barack Obama afraid to come out of the ...
# 975  No Pope has ever been tougher on illegal immig...
#
#                              harm_evidence  \
# 16                  political_interference
# 18                        non_identifiable
# 20                                   other
# 22                                   other
# 31                  political_interference
# ..                                     ...
# 971                       non_identifiable
# 972                 political_interference
# 973                 political_interference
# 974            discrimination,human_rights
# 975  political_interference,discrimination
#
#                                     communication_goal  \
# 16                                           education
# 18                satire,entertainment,harm_reputation
# 20                satire,entertainment,harm_reputation
# 22                satire,entertainment,harm_reputation
# 31   entertainment,harm_political_interference,acti...
# ..                                                 ...
# 971                     boost_reputation,entertainment
# 972       boost_reputation,harm_political_interference
# 973  false_info,harm_political_interference,harm_re...
# 974                         false_info,harm_reputation
# 975                            boost_reputation,satire
#
#                         core_frame  \
# 16                  human_interest
# 18                  human_interest
# 20                  human_interest
# 22         conflict,human_interest
# 31         responsibility,conflict
# ..                             ...
# 971                 human_interest
# 972                 human_interest
# 973  human_interest,responsibility
# 974                 human_interest
# 975  human_interest,responsibility
#
#                                                   hero  \
# 16                                               Biden
# 18   A leader who sounds smart and capable during s...
# 20   People expect that a VP can communicate with c...
# 22   The freedom for Trump and his squad to dress i...
# 31     Poso's supposters, those who share his ideology
# ..                                                 ...
# 971                         Donald Trump and Elon Musk
# 972                                      Donald Trump
# 973                                       Donald Trump
# 974                                            unclear
# 975                                       Donald Trump
#
#                                                villain  \
# 16                                               Putin
# 18   Kamala Harris rambling and not making sense du...
# 20     Online users believe that Harris is a rambler.
# 22                   Republicans who want to ban drag.
# 31   AOC, and other related gov. officials who shar...
# ..                                                 ...
# 971                                                NaN
# 972                                     Kamala Harris
# 973                                      Kamala Harris
# 974                                       Barack Obama
# 975                                 Illegal Immigrants
#
#                                                   plot  \
# 16                            Putin and Biden hugging
# 18   Kamala's speech does not make sense, which lea...
# 20   Kamala Harris is shown to be giving a speech t...
# 22   Republicans want to ban drag, but Donald Trump...
# 31   Biden and AOC do not understand how to priorit...
# ..                                                 ...
# 971                        Trump and Musk are friends
# 972                     The 2024 presidential election
# 973  Kamala Harris wants to create something like a...
# 974  Obama only legalized gay marriage for his own ...
# 975  Donald Trump must prevent illegal immigration ...
#
#                                                  moral            domain  \
# 16             U.S. and Russian leaders can get along        twitter.com
# 18   Kamala Harris's credibility as VP should be qu...       twitter.com
# 20   Kamala Harris is portrayed as being unable to ...  www.facebook.com
# 22   Republicans should stop calling for drag to be...       twitter.com
# 31   we must take a stand against their choices to ...       twitter.com
# ..                                                 ...               ...
# 971        Donald Trump and Elon Musk are a good team              x.com
# 972                             Vote for Donald Trump              x.com
# 973  Vote for a president who will keep government ...             x.com
# 974  Don't support someone who won't openly be hone...             x.com
# 975  Donald Trump will allow Americans to maintain ...             x.com
#
#        year
# 16   2023.0
# 18   2023.0
# 20   2023.0
# 22   2023.0
# 31   2023.0
# ..      ...
# 971  2024.0
# 972  2024.0
# 973  2024.0
# 974  2024.0
# 975  2024.0
#
# [714 rows x 59 columns]

# %% [markdown]
# [Cont from Yas]
# Let's just look at the _important_ content for now:

# %%
df1.columns
# Out:
# Index(['incident_id', 'report_id', 'date_coded', 'url', 'file', 'screenshot',
#        'date_posted', 'format', 'transcript', 'summary_content', 'type',
#        'comment_type', 'sharer_faketype', 'external_verification',
#        'links_verification', 'evidence_fake', 'watermark', 'likes', 'views',
#        'comments', 'shares', 'original_source_name', 'original_source_type',
#        'original_source_actor_type', 'original_source_country', 'sharer_name',
#        'sharer_type', 'sharer_job', 'high_impact_comment', 'sharer_country',
#        'sharer_city', 'target_name', 'target_one_name', 'target_one_sentiment',
#        'target_one_type_macro', 'target_one_type_micro', 'target_one_country',
#        'target_two_name', 'target_two_sentiment', 'target_two_type_macro',
#        'target_two_type_micro', 'target_two_country', 'target_type_macro',
#        'target_type_micro', 'target_country', 'deepfake_content_depicts',
#        'harm_depicted', 'social_policy_sector', 'context_deepfake',
#        'text_around_deepfake', 'harm_evidence', 'communication_goal',
#        'core_frame', 'hero', 'villain', 'plot', 'moral', 'domain', 'year'],
#       dtype='object')

# %% [markdown]
# Categorizing columns:
#
# <h3>Important for analysis</h3>
#
# Media:
# * **Visual:** 'format', 'file'
# * **Text:** 'transcript', 'summary_content', 'type',
# * **Engagement metrics:** 'likes', 'views', 'comments', 'shares'
#
# Personas: _who is the original source/sharer/target of the deepfake_
# * **Source**: 'original_source_type', 'original_source_actor_type', 'original_source_country'
# * **Sharer**: 'sharer_type', 'sharer_job', 'high_impact_comment', 'sharer_country', 'sharer_city'
# * **Target**: 'target_name', 'target_one_name', 'target_one_sentiment', 'target_one_type_macro', 'target_one_type_micro', 'target_one_country', 'target_two_name', 'target_two_sentiment', 'target_two_type_macro', 'target_two_type_micro', 'target_two_country', 'target_type_macro', 'target_type_micro', 'target_country'
#
# Context \& Content:
# * **Content**: 'deepfake_content_depicts', 'harm_depicted', 'communication_goal', 'core_frame'
# * **Real-world connection**: 'context_deepfake', 'text_around_deepfake', 'harm_evidence'
# * **Politics/policy**: 'social_policy_sector', 'hero', 'villain', 'plot', 'moral'
#
# <h3>Not as important for now</h3>
#
# * **Descriptive**: 'year', 'domain'
# * **Extra metadata**: 'url', 'screenshot'
# * **Names of distributors**: 'original_source_name', 'sharer_name',
# * **For verification**: 'external_verification', 'comment_type', 'links_verification', 'evidence_fake'
# * **Misc**: 'incident_id', 'report_id', 'date_coded', 'date_posted', 'type' (just 'deepfake'), 'sharer_faketype', 'watermark'

# %%
# Not sure if we're going to use df1 or df2 yet, depending on how complicated it is to process video
# So let's save both for now
df1.to_csv('data-2324-ver.csv', index=False)
df2.to_csv('data-2324-no-ver.csv', index=False)
